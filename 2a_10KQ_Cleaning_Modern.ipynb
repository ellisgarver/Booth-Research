# %%
import os
import re
from bs4 import BeautifulSoup

###############################################################################
# PART 1 — CLEAN HTML BUT PRESERVE INLINE XBRL TEXT
###############################################################################

def clean_html_file(filepath):
    with open(filepath, "r", encoding="utf-8", errors="ignore") as f:
        raw = f.read()

    soup = BeautifulSoup(raw, "lxml")

    # Remove tables (NOTE: flattening sometimes loses text layout,
    # but you asked to preserve your original code's structure)
    for t in soup.find_all(["table", "tr", "td", "th"]):
        t.decompose()

    # Remove images / figures
    for t in soup.find_all(["img", "figure"]):
        t.decompose()

    # Remove script/style
    for t in soup(["script", "style"]):
        t.decompose()

    # Inline XBRL tags like <ix:nonNumeric>, <us-gaap:Something>
    for t in soup.find_all():
        if ":" in (t.name or ""):
            t.unwrap()

    text = soup.get_text(separator="\n")

    # Remove page numbers alone on a line
    text = re.sub(r"\n\s*\d{1,6}\s*(?=\n)", "\n", text)

    # Remove boilerplate
    boiler = [
        r"United States Securities and Exchange Commission",
        r"Form\s+10-K",
        r"Form\s+10-Q",
        r"TABLE OF CONTENTS",
        r"Indicate.*?by checkmark",
    ]
    for bp in boiler:
        text = re.sub(bp, " ", text, flags=re.IGNORECASE | re.DOTALL)

    # Whitespace cleanup
    text = re.sub(r"[ \t]+", " ", text)
    text = re.sub(r"\n\s*\n+", "\n\n", text)

    return text.strip()


###############################################################################
# PART 2 — ITEM & MD&A HEADING REGEX
###############################################################################

# Generic "Item X" finder (used ONLY for start anchoring)
ITEM_FINDER = re.compile(
    r"(?<!\w)item[\s\.\-–—:]*\d+[a-z]?(?!\w)",
    flags=re.IGNORECASE
)

def item_header_regex(num):
    return rf"(?<!\w)item[\s\.\-–—:]*{num}(?!\w)"

# 10-K MD&A = Item 7
TEN_K_MDA_ITEM = item_header_regex(7)

# 10-Q MD&A = Item 2
TEN_Q_MDA_ITEM = item_header_regex(2)

# Full MD&A heading
MDA_HEADING = re.compile(
    r"management['’`s]{0,2}\s+discussion\s+and\s+analysis",
    flags=re.IGNORECASE
)


###############################################################################
# PART 3 — RELIABLE END BOUNDARIES
###############################################################################
# These match ONLY true section headers, not inline references.

END_10Q = re.compile(
    r"(?mi)^[ \t]*(item\s*)?3[\.\-–—:]?[ \t]*($|\n)"
)

END_10K = re.compile(
    r"(?mi)^[ \t]*(item\s*)?8[\.\-–—:]?[ \t]*($|\n)"
)


###############################################################################
# PART 4 — DETERMINE FILING TYPE FROM FILE NAME
###############################################################################

def filing_type_from_filename(path):
    name = os.path.basename(path).lower()
    if "10k" in name:
        return "10-K"
    if "10q" in name:
        return "10-Q"
    return "10-K"


###############################################################################
# PART 5 — EXTRACT MD&A
###############################################################################

def extract_mda(text, filing_type):
    low = text.lower()

    # Precompute START locations (for anchoring only)
    item_positions = [m.start() for m in ITEM_FINDER.finditer(low)]

    ###########################################################################
    # STEP 1 — MD&A Heading Detected
    ###########################################################################
    heading = MDA_HEADING.search(low)

    if heading:
        heading_start = heading.start()

        # Try to anchor start at nearest correct Item 7 or Item 2
        start = heading_start
        prev_items = [p for p in item_positions if p < heading_start]

        if prev_items:
            cand = prev_items[-1]
            snippet = low[cand:cand + 60]
            if filing_type == "10-K" and re.search(TEN_K_MDA_ITEM, snippet):
                start = cand
            elif filing_type == "10-Q" and re.search(TEN_Q_MDA_ITEM, snippet):
                start = cand

        # END boundary: Item 8 for 10-K, Item 3 for 10-Q
        if filing_type == "10-K":
            end_match = END_10K.search(text, pos=start + 30)
        else:
            end_match = END_10Q.search(text, pos=start + 30)

        end = end_match.start() if end_match else len(text)
        return text[start:end].strip()

    ###########################################################################
    # STEP 2 — FALLBACK: Look for Item 7/2 + "discussion and analysis"
    ###########################################################################
    item_pattern = TEN_K_MDA_ITEM if filing_type == "10-K" else TEN_Q_MDA_ITEM

    mda_item_start = None
    for m in re.finditer(item_pattern, low):
        s = m.start()
        window = low[s:s+800]
        if "discussion" in window and "analysis" in window:
            mda_item_start = s
            break

    if mda_item_start is None:
        return ""

    # END boundary
    if filing_type == "10-K":
        end_match = END_10K.search(text, pos=mda_item_start + 30)
    else:
        end_match = END_10Q.search(text, pos=mda_item_start + 30)

    end = end_match.start() if end_match else len(text)
    return text[mda_item_start:end].strip()


###############################################################################
# PART 6 — PROCESS ONE FILE (MD&A ONLY)
###############################################################################

def process_one_file(input_file, output_base):
    out = output_base + "_cleaned.txt"
    if os.path.exists(out):
        print("Skipping (exists):", out)
        return

    cleaned = clean_html_file(input_file)
    filing_type = filing_type_from_filename(input_file)
    mda = extract_mda(cleaned, filing_type)

    with open(out, "w") as f:
        f.write("===== MD&A =====\n\n")
        f.write(mda if mda else "(MD&A not found)")

    print(f"✔ Saved MD&A → {out}")


###############################################################################
# PART 7 — BATCH PROCESS DIRECTORY
###############################################################################

def process_all_files(src, dst):
    for root, _, files in os.walk(src):
        for file in files:
            if file.lower().endswith(".htm"):
                inp = os.path.join(root, file)
                rel = os.path.relpath(root, src)
                out_dir = os.path.join(dst, rel)
                os.makedirs(out_dir, exist_ok=True)
                out_base = os.path.join(out_dir, file.rsplit(".", 1)[0])
                process_one_file(inp, out_base)


###############################################################################
# PART 8 — MAIN
###############################################################################

if __name__ == "__main__":
    src_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original"
    dst_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1"
    process_all_files(src_folder, dst_folder)
# Out:
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2020-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2006-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2007-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2016-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2016-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2020-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2006-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2007-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2020-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2016-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2007-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2016-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2007-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q2-10K-A_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2025-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2021-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2023-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2022-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2019-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2020-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2017-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2018-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2024-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2023-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2019-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2025-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2024-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2020-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2018-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2021-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2022-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2022-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2023-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2018-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2021-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2019-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2025-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2024-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2017-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2020-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2021-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2019-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2020-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2017-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2023-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2022-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2018-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2024-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2025-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2020-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2017-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2021-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2016-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2021-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2016-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2017-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2020-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2024-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2024-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2014-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2023-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2023-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2015-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2022-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2019-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2019-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2018-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q4-10Q-A_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2018-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2022-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2015-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2024-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2016-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2021-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2024-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2021-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2016-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2020-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2017-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2020-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2017-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2019-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2023-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2014-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2015-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2022-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2015-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2022-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2014-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2023-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2018-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2018-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2019-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2022-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2018-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2019-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2019-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2018-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2023-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2023-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2022-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2025-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2020-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2017-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2024-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2024-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2025-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2017-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2020-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2016-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2021-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2016-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2021-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2018-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2018-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2019-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2022-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2022-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2023-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2023-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2019-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2016-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2021-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2024-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2017-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2020-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2017-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2020-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2021-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2016-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2024-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2025-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2025-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2020-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2020-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2021-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2024-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2025-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2025-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2021-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2024-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2019-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2018-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2023-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2022-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2022-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2023-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2019-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2024-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2024-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2025-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2020-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2021-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2021-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2025-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2020-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2022-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2018-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2018-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2019-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2019-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2022-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2023-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2023-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2022-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2022-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2023-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2023-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2024-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2024-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2020-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2025-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2021-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2021-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2020-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2025-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2023-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2022-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2022-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2023-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2020-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2020-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2024-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2021-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2025-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2025-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2024-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2021-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2025-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2020-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2017-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2022-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2022-Q4-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2015-Q4-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2018-Q4-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2018-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2025-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2017-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2020-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2015-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2022-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2018-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2025-Q4-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2025-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2018-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2017-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2020-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2017-Q4-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2020-Q4-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2022-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2015-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2023-Q4-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2023-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2019-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2019-Q4-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2016-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2021-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2024-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2021-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2016-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2024-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2019-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2016-Q4-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2021-Q4-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2016-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2021-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2023-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2023-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2019-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2024-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAPL/AAPL-2024-Q4-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2025-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2017-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2020-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2024-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2024-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2019-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2025-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2020-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2017-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2021-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2016-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2021-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2016-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2018-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2017-Q4-10Q-A_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2022-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2015-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2023-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2023-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2022-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2019-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2018-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2021-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2016-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2024-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2020-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2017-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2020-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2017-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2016-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2021-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2024-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2025-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2025-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2015-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2022-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2022-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2023-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2018-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2018-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2019-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/KHC/KHC-2023-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2018-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2022-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2022-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2023-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2023-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2018-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2019-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2019-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2024-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2024-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2025-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2017-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2020-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2021-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2021-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2025-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2020-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2023-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2022-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2022-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2019-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2018-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2018-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2019-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2023-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2020-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2017-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2020-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2021-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2024-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2025-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2025-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2024-Q2-10K-A_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2021-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/AAP/AAP-2024-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CMCSA/CMCSA-2022-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CMCSA/CMCSA-2018-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CMCSA/CMCSA-2019-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CMCSA/CMCSA-2019-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CMCSA/CMCSA-2018-Q2-10Q_cleaned.txt
# ...
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2025-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2020-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2017-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2021-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2016-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2021-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2016-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2018-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2022-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2015-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2015-Q1-10K-A_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2014-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2023-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2014-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2023-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2015-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2022-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2019-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2019-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2018-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2021-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2016-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2024-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2020-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2017-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2020-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2017-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2016-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2021-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2024-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2025-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2025-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2015-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2022-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2015-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2022-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2014-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2023-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2018-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2018-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2019-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2019-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2023-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/MSCI/MSCI-2014-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/GLW/GLW-2024-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/GLW/GLW-2021-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/GLW/GLW-2025-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/GLW/GLW-2025-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/GLW/GLW-2024-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/GLW/GLW-2021-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/GLW/GLW-2023-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/GLW/GLW-2022-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/GLW/GLW-2022-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/GLW/GLW-2023-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/GLW/GLW-2025-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/GLW/GLW-2021-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/GLW/GLW-2021-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/GLW/GLW-2025-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/GLW/GLW-2024-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/GLW/GLW-2024-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/GLW/GLW-2023-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/GLW/GLW-2023-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/GLW/GLW-2022-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/GLW/GLW-2022-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2014-Q2-10K-A_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2018-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2019-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2019-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2015-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2022-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2014-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2023-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2014-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2023-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2022-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2015-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2011-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2018-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2021-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2016-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2021-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2016-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2020-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2017-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2025-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2012-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2013-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2024-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2013-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2024-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2017-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2020-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2012-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2025-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2023-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2014-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2019-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2019-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2018-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2018-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2011-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2014-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2023-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2015-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2022-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2015-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2022-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2012-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2025-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2012-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2025-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2013-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2024-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2017-Q2-10K-A_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2016-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2021-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2012-Q1-10K-A_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2015-Q1-10K-A_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2016-Q2-10K-A_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2020-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2017-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2020-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2017-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2024-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2013-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2021-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/VNO/VNO-2016-Q2-10Q_cleaned.txt

# %%
import os
import re
from bs4 import BeautifulSoup

###############################################################################
# PART 1 — CLEAN HTML BUT PRESERVE INLINE XBRL TEXT
###############################################################################

def clean_html_file(filepath):
    with open(filepath, "r", encoding="utf-8", errors="ignore") as f:
        raw = f.read()

    soup = BeautifulSoup(raw, "lxml")

    # Remove tables (layout / numbers in tables are usually duplicated in text)
    for t in soup.find_all(["table", "tr", "td", "th"]):
        t.decompose()

    # Remove images / figures
    for t in soup.find_all(["img", "figure"]):
        t.decompose()

    # Remove script/style
    for t in soup(["script", "style"]):
        t.decompose()

    # Inline XBRL tags like <ix:nonNumeric>, <us-gaap:Whatever>:
    # unwrap the tag but KEEP the text content.
    for t in soup.find_all():
        if ":" in (t.name or ""):
            t.unwrap()

    text = soup.get_text(separator="\n")

    # Remove page numbers that appear alone on a line
    text = re.sub(r"\n\s*\d{1,6}\s*(?=\n)", "\n", text)

    # Remove some boilerplate
    boiler = [
        r"United States Securities and Exchange Commission",
        r"Form\s+10-K",
        r"Form\s+10-Q",
        r"TABLE OF CONTENTS",
        r"Indicate.*?by checkmark",
    ]
    for bp in boiler:
        text = re.sub(bp, " ", text, flags=re.IGNORECASE | re.DOTALL)

    # Whitespace cleanup
    text = re.sub(r"[ \t]+", " ", text)
    text = re.sub(r"\n\s*\n+", "\n\n", text)

    return text.strip()


###############################################################################
# PART 2 — ITEM & MD&A HEADING REGEX
###############################################################################

# Generic "Item X" finder
ITEM_FINDER = re.compile(
    r"(?<!\w)item[\s\.\-–—:]*\d+[a-z]?(?!\w)",
    flags=re.IGNORECASE
)

def item_header_regex(num):
    return rf"(?<!\w)item[\s\.\-–—:]*{num}(?!\w)"


# For MD&A items
TEN_K_MDA_ITEM = item_header_regex(7)  # Item 7
TEN_Q_MDA_ITEM = item_header_regex(2)  # Item 2

# STRICT MD&A heading phrase (main anchor)
MDA_HEADING = re.compile(
    r"management['’`s]{0,2}\s+discussion\s+and\s+analysis",
    flags=re.IGNORECASE
)


###############################################################################
# PART 3 — DETERMINE FILING TYPE FROM FILE NAME
###############################################################################

def filing_type_from_filename(path):
    name = os.path.basename(path).lower()
    if "10k" in name:
        return "10-K"
    if "10q" in name:
        return "10-Q"
    # Fallback if naming is weird
    return "10-K"


###############################################################################
# PART 4 — EXTRACT MD&A SECTION (10-K: Item 7, 10-Q: Item 2)
###############################################################################

def extract_mda(text, filing_type):
    """
    1) Find 'Management's Discussion and Analysis...' heading.
    2) Anchor start at the preceding correct Item 7/2 header if present.
    3) End at the next 'Item X' header.
    4) If no heading found, fallback to Item 7/2 ONLY when 'discussion and analysis'
       appears close to it (to avoid cross-references).
    """
    low = text.lower()

    # Precompute all item header positions
    item_positions = [m.start() for m in ITEM_FINDER.finditer(low)]

    # --- Step 1: Try to find the actual MD&A heading phrase ---
    heading_match = MDA_HEADING.search(low)

    if heading_match:
        heading_start = heading_match.start()

        # Find the nearest preceding item header
        prev_items = [p for p in item_positions if p < heading_start]
        start = heading_start
        if prev_items:
            candidate = prev_items[-1]
            header_snippet = low[candidate:candidate+40]

            if filing_type == "10-K" and re.search(TEN_K_MDA_ITEM, header_snippet):
                start = candidate
            elif filing_type == "10-Q" and re.search(TEN_Q_MDA_ITEM, header_snippet):
                start = candidate

        # Find the next item header after the heading (or after the start)
        next_items = [p for p in item_positions if p > heading_start]
        end = next_items[0] if next_items else len(text)

        return text[start:end].strip()

    # --- Step 2: Fallback — No explicit heading found ---
    # We now look for the MD&A item (7 for 10-K, 2 for 10-Q),
    # but we require 'discussion and analysis' near it.

    item_pattern = TEN_K_MDA_ITEM if filing_type == "10-K" else TEN_Q_MDA_ITEM

    mda_item_start = None

    for m in re.finditer(item_pattern, low):
        s = m.start()
        window = low[s:s+600]  # look ahead a bit
        if re.search(r"discussion\s+and\s+analysis", window, flags=re.IGNORECASE):
            mda_item_start = s
            break

    if mda_item_start is None:
        return ""  # No reliable MD&A found

    # Next item boundary after the MD&A item
    next_items = [p for p in item_positions if p > mda_item_start]
    end = next_items[0] if next_items else len(text)

    return text[mda_item_start:end].strip()


###############################################################################
# PART 5 — PROCESS ONE FILE (MD&A ONLY)
###############################################################################

def process_one_file(input_file, output_base):
    out = output_base + "_cleaned.txt"
    if os.path.exists(out):
        print("Skipping (exists):", out)
        return

    cleaned = clean_html_file(input_file)
    filing_type = filing_type_from_filename(input_file)

    mda = extract_mda(cleaned, filing_type)

    with open(out, "w") as f:
        f.write("===== MD&A =====\n\n")
        f.write(mda if mda else "(MD&A not found)")

    print(f"✔ Saved MD&A → {out}")


###############################################################################
# PART 6 — BATCH OVER DIRECTORY
###############################################################################

def process_all_files(src, dst):
    for root, _, files in os.walk(src):
        for file in files:
            if file.lower().endswith(".htm"):
                inp = os.path.join(root, file)
                rel = os.path.relpath(root, src)
                out_dir = os.path.join(dst, rel)
                os.makedirs(out_dir, exist_ok=True)
                out_base = os.path.join(out_dir, file.rsplit(".", 1)[0])
                process_one_file(inp, out_base)


###############################################################################
# PART 7 — RUN
###############################################################################

if __name__ == "__main__":
    src_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original"
    dst_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1"
    process_all_files(src_folder, dst_folder)
# Out:
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2020-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2006-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2007-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2016-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2016-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2020-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2006-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2007-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2020-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2016-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2007-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2016-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2007-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q2-10K-A_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2025-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2021-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2023-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2022-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2019-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2020-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2017-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2018-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2024-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2023-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2019-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2025-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2024-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2020-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2018-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2021-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2022-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2022-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2023-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2018-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2021-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2019-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2025-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2024-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2017-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2020-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2021-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2019-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2020-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2017-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2023-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2022-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2018-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2024-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2025-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2020-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2017-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2021-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2016-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2021-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2016-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2017-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2020-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2024-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2024-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2014-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2023-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2023-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2015-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2022-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2019-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2019-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2018-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q4-10Q-A_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2018-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2022-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2015-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2024-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2016-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2021-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2024-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2021-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2016-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2020-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2017-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2020-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2017-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2019-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2023-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2014-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2015-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2022-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2015-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2022-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2014-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2023-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2018-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2018-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2019-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2022-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2018-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2019-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2019-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2018-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2023-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2023-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2022-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2025-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2020-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2017-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2024-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2024-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2025-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2017-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2020-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2016-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2021-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2016-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2021-Q4-10Q_cleaned.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[78], line 206
#     204 src_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original"
#     205 dst_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1"
# --> 206 process_all_files(src_folder, dst_folder)
#
# Cell In[78], line 196, in process_all_files(src, dst)
#     194 os.makedirs(out_dir, exist_ok=True)
#     195 out_base = os.path.join(out_dir, file.rsplit(".", 1)[0])
# --> 196 process_one_file(inp, out_base)
#
# Cell In[78], line 171, in process_one_file(input_file, output_base)
#     168     print("Skipping (exists):", out)
#     169     return
# --> 171 cleaned = clean_html_file(input_file)
#     172 filing_type = filing_type_from_filename(input_file)
#     174 mda = extract_mda(cleaned, filing_type)
#
# Cell In[78], line 17, in clean_html_file(filepath)
#      15 # Remove tables (layout / numbers in tables are usually duplicated in text)
#      16 for t in soup.find_all(["table", "tr", "td", "th"]):
# ---> 17     t.decompose()
#      19 # Remove images / figures
#      20 for t in soup.find_all(["img", "figure"]):
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/element.py:1466, in Tag.decompose(self)
#    1455 def decompose(self):
#    1456     """Recursively destroys this PageElement and its children.
#    1457
#    1458     This element will be removed from the tree and wiped out; so
#    (...)
#    1464     `decomposed` property.
#    1465     """
# -> 1466     self.extract()
#    1467     i = self
#    1468     while i is not None:
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/element.py:381, in PageElement.extract(self, _self_index)
#     378 if (self.previous_sibling is not None
#     379     and self.previous_sibling is not self.next_sibling):
#     380     self.previous_sibling.next_sibling = self.next_sibling
# --> 381 if (self.next_sibling is not None
#     382     and self.next_sibling is not self.previous_sibling):
#     383     self.next_sibling.previous_sibling = self.previous_sibling
#     384 self.previous_sibling = self.next_sibling = None
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/element.py:1620, in Tag.__getattr__(self, tag)
#    1618 # We special case contents to avoid recursion.
#    1619 elif not tag.startswith("__") and not tag == "contents":
# -> 1620     return self.find(tag)
#    1621 raise AttributeError(
#    1622     "'%s' object has no attribute '%s'" % (self.__class__, tag))
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/element.py:2001, in Tag.find(self, name, attrs, recursive, string, **kwargs)
#    1984 """Look in the children of this PageElement and find the first
#    1985 PageElement that matches the given criteria.
#    1986
#    (...)
#    1998 :rtype: bs4.element.Tag | bs4.element.NavigableString
#    1999 """
#    2000 r = None
# -> 2001 l = self.find_all(name, attrs, recursive, string, 1, _stacklevel=3,
#    2002                   **kwargs)
#    2003 if l:
#    2004     r = l[0]
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/element.py:2008, in Tag.find_all(self, name, attrs, recursive, string, limit, **kwargs)
#    2005     return r
#    2006 findChild = find #BS2
# -> 2008 def find_all(self, name=None, attrs={}, recursive=True, string=None,
#    2009              limit=None, **kwargs):
#    2010     """Look in the children of this PageElement and find all
#    2011     PageElements that match the given criteria.
#    2012
#    (...)
#    2024     :rtype: bs4.element.ResultSet
#    2025     """
#    2026     generator = self.descendants
#
# KeyboardInterrupt:

# %%
# very close, but still does not always get the right thing
import os
import re
from bs4 import BeautifulSoup

###############################################################################
# PART 1 — CLEAN HTML BUT PRESERVE INLINE XBRL TEXT
###############################################################################

def clean_html_file(filepath):
    with open(filepath, "r", encoding="utf-8", errors="ignore") as f:
        raw = f.read()

    soup = BeautifulSoup(raw, "lxml")

    # Remove tables (visual layout only — MD&A rarely inside <table>)
    for t in soup.find_all(["table", "tr", "td", "th"]):
        t.decompose()

    # Remove images
    for t in soup.find_all(["img", "figure"]):
        t.decompose()

    # Remove script/style
    for t in soup(["script", "style"]):
        t.decompose()

    # Inline XBRL unwrap (keeps the text instead of deleting it)
    for t in soup.find_all():
        if ":" in (t.name or ""):  # <ix:nonNumeric>
            t.unwrap()

    text = soup.get_text(separator="\n")

    # Remove page numbers
    text = re.sub(r"\n\s*\d{1,6}\s*(?=\n)", "\n", text)

    # Remove boilerplate
    boiler = [
        r"United States Securities and Exchange Commission",
        r"Form\s+10-K",
        r"Form\s+10-Q",
        r"TABLE OF CONTENTS",
        r"Indicate.*?by checkmark",
    ]
    for bp in boiler:
        text = re.sub(bp, " ", text, flags=re.IGNORECASE | re.DOTALL)

    # Clean whitespace
    text = re.sub(r"[ \t]+", " ", text)
    text = re.sub(r"\n\s*\n+", "\n\n", text)

    return text.strip()


###############################################################################
# PART 2 — UNIVERSAL ITEM REGEX
###############################################################################

ITEM_FINDER = re.compile(
    r"(?<!\w)item[\s\.\-–—:]*\d+[a-z]?(?!\w)",
    flags=re.IGNORECASE
)

def item_header_regex(num):
    return rf"(?<!\w)item[\s\.\-–—:]*{num}(?!\w)"


# MD&A identifiers
TEN_K_MDA_HEADER = item_header_regex(7)
TEN_Q_MDA_HEADER = item_header_regex(2)

# MD&A verification keywords (must match near header)
MDA_KEYWORDS = [
    "management",
    "discussion",
    "analysis",
    "results of operations",
    "liquidity",
    "capital resources"
]


###############################################################################
# PART 3 — DETERMINE FILING TYPE **FROM FILE NAME**
###############################################################################

def filing_type_from_filename(path):
    name = os.path.basename(path).lower()
    if "10k" in name:
        return "10-K"
    if "10q" in name:
        return "10-Q"
    # fallback but rarely needed
    return "10-K"


###############################################################################
# PART 4 — EXTRACT FULL MD&A WITH HEADER VALIDATION
###############################################################################

def extract_mda(text, filing_type):

    low = text.lower()

    # Choose item number based on correct rules
    pattern = TEN_K_MDA_HEADER if filing_type == "10-K" else TEN_Q_MDA_HEADER

    # Find all matching locations (Item 7 or Item 2)
    matches = list(re.finditer(pattern, low))
    if not matches:
        return ""

    # Choose the first header that looks like REAL MD&A
    mda_header = None
    for m in matches:
        start = m.start()

        # Look ahead 500 characters for MD&A keywords
        window = low[start:start+500]
        if any(k in window for k in MDA_KEYWORDS):
            mda_header = m
            break

    if mda_header is None:
        return ""  # Prevents extracting Properties or cross-references

    start = mda_header.start()

    # Find next item boundary for end of MD&A
    boundaries = sorted({p.start() for p in ITEM_FINDER.finditer(low)})
    next_bounds = [b for b in boundaries if b > start]
    end = next_bounds[0] if next_bounds else len(text)

    chunk = text[start:end].strip()

    return chunk


###############################################################################
# PART 5 — PROCESS ONE FILE
###############################################################################

def process_one_file(input_file, output_base):

    out = output_base + "_cleaned.txt"
    if os.path.exists(out):
        print("Skipping:", out)
        return

    cleaned = clean_html_file(input_file)
    ftype = filing_type_from_filename(input_file)

    mda = extract_mda(cleaned, ftype)

    with open(out, "w") as f:
        f.write("===== MD&A =====\n\n")
        f.write(mda if mda else "(MD&A not found)")

    print("✔ Saved MD&A →", out)


###############################################################################
# PART 6 — PROCESS DIRECTORY
###############################################################################

def process_all_files(src, dst):
    for root, _, files in os.walk(src):
        for file in files:
            if file.lower().endswith(".htm"):
                inp = os.path.join(root, file)
                rel = os.path.relpath(root, src)
                out_dir = os.path.join(dst, rel)
                os.makedirs(out_dir, exist_ok=True)
                out_base = os.path.join(out_dir, file.rsplit(".", 1)[0])
                process_one_file(inp, out_base)


###############################################################################
# PART 7 — RUN
###############################################################################

if __name__ == "__main__":
    src_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original"
    dst_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1"
    process_all_files(src_folder, dst_folder)
# Out:
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2020-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2006-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2007-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2016-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2016-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2020-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2006-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2007-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2020-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2016-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2007-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2016-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2007-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q2-10K-A_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2025-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2021-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2023-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2022-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2019-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2020-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2017-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2018-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2024-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2023-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2019-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2025-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2024-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2020-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2018-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2021-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2022-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2022-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2023-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2018-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2021-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2019-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2025-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2024-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2017-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2020-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2021-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2019-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2020-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2017-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2023-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2022-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2018-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2024-Q2-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2025-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2020-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2017-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2021-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2016-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2021-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2016-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2017-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2020-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2024-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2024-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2014-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2023-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2023-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2015-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2022-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2019-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2019-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2018-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q4-10Q-A_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2018-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2022-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2015-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2024-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2016-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2021-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2024-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2021-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2016-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2020-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2017-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2020-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2017-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2019-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2023-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2014-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2015-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2022-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2015-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2022-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2014-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2023-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2018-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2018-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2019-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2022-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2018-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2019-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2019-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2018-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2023-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2023-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2022-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2025-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2020-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2017-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2024-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2024-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2025-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2017-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2020-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2016-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2021-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2016-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2021-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2018-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2018-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2019-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2022-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2022-Q1-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2023-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2023-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2019-Q3-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2016-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2021-Q2-10Q_cleaned.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[69], line 185
#     183 src_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original"
#     184 dst_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1"
# --> 185 process_all_files(src_folder, dst_folder)
#
# Cell In[69], line 175, in process_all_files(src, dst)
#     173 os.makedirs(out_dir, exist_ok=True)
#     174 out_base = os.path.join(out_dir, file.rsplit(".", 1)[0])
# --> 175 process_one_file(inp, out_base)
#
# Cell In[69], line 150, in process_one_file(input_file, output_base)
#     147     print("Skipping:", out)
#     148     return
# --> 150 cleaned = clean_html_file(input_file)
#     151 ftype = filing_type_from_filename(input_file)
#     153 mda = extract_mda(cleaned, ftype)
#
# Cell In[69], line 13, in clean_html_file(filepath)
#      10 with open(filepath, "r", encoding="utf-8", errors="ignore") as f:
#      11     raw = f.read()
# ---> 13 soup = BeautifulSoup(raw, "lxml")
#      15 # Remove tables (visual layout only — MD&A rarely inside <table>)
#      16 for t in soup.find_all(["table", "tr", "td", "th"]):
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/__init__.py:335, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333 self.builder.initialize_soup(self)
#     334 try:
# --> 335     self._feed()
#     336     success = True
#     337     break
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/__init__.py:478, in BeautifulSoup._feed(self)
#     475 # Convert the document to Unicode.
#     476 self.builder.reset()
# --> 478 self.builder.feed(self.markup)
#     479 # Close out any unfinished strings and close all the open tags.
#     480 self.endData()
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/builder/_lxml.py:379, in LXMLTreeBuilder.feed(self, markup)
#     377     self.parser = self.parser_for(encoding)
#     378     self.parser.feed(markup)
# --> 379     self.parser.close()
#     380 except (UnicodeDecodeError, LookupError, etree.ParserError) as e:
#     381     raise ParserRejectedMarkup(e)
#
# File src/lxml/parser.pxi:1383, in lxml.etree._FeedParser.close()
#
# File src/lxml/parser.pxi:1414, in lxml.etree._FeedParser.close()
#
# File src/lxml/parsertarget.pxi:168, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src/lxml/parsertarget.pxi:156, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src/lxml/etree.pyx:334, in lxml.etree._ExceptionContext._raise_if_stored()
#
# File src/lxml/saxparser.pxi:443, in lxml.etree._handleSaxTargetStartNoNs()
#
# File src/lxml/saxparser.pxi:458, in lxml.etree._callTargetSaxStart()
#
# File src/lxml/parsertarget.pxi:94, in lxml.etree._PythonSaxParserTarget._handleSaxStart()
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/builder/_lxml.py:289, in LXMLTreeBuilderForXML.start(self, name, attrs, nsmap)
#     285 # Namespaces are in play. Find any attributes that came in
#     286 # from lxml with namespaces attached to their names, and
#     287 # turn then into NamespacedAttribute objects.
#     288 new_attrs = {}
# --> 289 for attr, value in list(attrs.items()):
#     290     namespace, attr = self._getNsTag(attr)
#     291     if namespace is None:
#
# KeyboardInterrupt:

# %%
import os
import re
from bs4 import BeautifulSoup

###############################################################################
# PART 1 — CLEAN HTML WHILE PRESERVING INLINE XBRL TEXT
###############################################################################

def clean_html_file(filepath):
    """Cleans HTML but *preserves* all XBRL/inline-XBRL text."""
    with open(filepath, "r", encoding="utf-8", errors="ignore") as f:
        raw = f.read()

    soup = BeautifulSoup(raw, "lxml")

    # Remove tables (usually formatting-only)
    for t in soup.find_all(["table", "tr", "td", "th"]):
        t.decompose()

    # Remove images
    for t in soup.find_all(["img", "figure"]):
        t.decompose()

    # Remove script/style
    for t in soup(["script", "style"]):
        t.decompose()

    # Important fix:
    # Inline XBRL tags have names like ix:nonNumeric, us-gaap:Revenue.
    # We REMOVE the tag wrapper but KEEP the text.
    for t in soup.find_all():
        if ":" in (t.name or ""):
            t.unwrap()   # <--- FIX: unwrap keeps text

    # Extract text
    text = soup.get_text(separator="\n")

    # Remove page numbers
    text = re.sub(r"\n\s*\d{1,5}\s*(?=\n)", "\n", text)

    # Remove boilerplate
    boiler = [
        r"United States Securities and Exchange Commission",
        r"Form\s+10-K",
        r"Form\s+10-Q",
        r"TABLE OF CONTENTS",
        r"Indicate.*?by checkmark",
    ]
    for bp in boiler:
        text = re.sub(bp, " ", text, flags=re.IGNORECASE | re.DOTALL)

    # Whitespace cleanup
    text = re.sub(r"[ \t]+", " ", text)
    text = re.sub(r"\n\s*\n+", "\n\n", text)

    return text.strip()


###############################################################################
# PART 2 — FLEXIBLE ITEM HEADER REGEX
###############################################################################

def item_header_regex(num, letter=""):
    """
    Matches ITEM 7, ITEM7, ITEM—7, Item 7: Management Discussion, etc.
    """
    ident = f"{num}{letter}".lower()
    return (
        r"(?<!\w)"
        r"item"
        r"[\s\.\-–—:]*"
        r"(" + ident + r")"
        r"(?![\w])"
    )


# For MD&A extraction only:
TEN_K_MDA = item_header_regex(7)
TEN_Q_MDA = item_header_regex(2)

# Fallback keywords
MDA_KEYWORDS = [
    r"management.{0,40}discussion",
    r"md&a",
    r"m d & a",
    r"mda",
]


###############################################################################
# PART 3 — FIND ALL ITEM HEADERS
###############################################################################

ITEM_FINDER = re.compile(
    r"(?<!\w)item[\s\.\-–—:]*\d+[a-z]?(?!\w)",
    flags=re.IGNORECASE
)


def extract_mda(text, filing_type):
    """Extract ONLY MD&A section using item boundaries + fallback."""

    low = text.lower()

    # Choose correct item number
    pattern = TEN_K_MDA if filing_type == "10-K" else TEN_Q_MDA

    # Try main MD&A detection
    m = re.search(pattern, low)

    # Fallback detection if missing
    if not m:
        for kw in MDA_KEYWORDS:
            mk = re.search(kw, low)
            if mk:
                m = mk
                break

    if not m:
        return ""  # MD&A missing entirely

    start = m.start()

    # Find next item boundary to determine end
    boundaries = sorted({p.start() for p in ITEM_FINDER.finditer(low)})
    next_bounds = [b for b in boundaries if b > start]
    end = next_bounds[0] if next_bounds else len(text)

    chunk = text[start:end].strip()

    # Remove PART headers that sometimes appear at top
    chunk = re.sub(r"^part\s+[ivx]+\s+", "", chunk, flags=re.IGNORECASE)

    return chunk


###############################################################################
# PART 4 — Detect filing type (10-K vs 10-Q)
###############################################################################

def detect_filing_type(text):
    low = text.lower()
    if "form 10-k" in low:
        return "10-K"
    if "form 10-q" in low:
        return "10-Q"

    # Fallback: if Item 2 exists, it's almost always a 10-Q
    if re.search(item_header_regex(2), low):
        return "10-Q"

    return "10-K"


###############################################################################
# PART 5 — Process one file (MD&A only)
###############################################################################

def process_one_file(input_file, output_base):

    out = output_base + "_cleaned.txt"
    if os.path.exists(out):
        print("Skipping (exists):", out)
        return

    cleaned = clean_html_file(input_file)
    ftype = detect_filing_type(cleaned)

    mda = extract_mda(cleaned, ftype)

    with open(out, "w") as f:
        f.write("===== MD&A =====\n\n")
        f.write(mda if mda else "(MD&A not found)")

    print("✔ Saved MD&A →", out)


###############################################################################
# PART 6 — Batch process directory
###############################################################################

def process_all_files(src, dst):
    for root, _, files in os.walk(src):
        for file in files:
            if file.lower().endswith(".htm"):
                inp = os.path.join(root, file)
                rel = os.path.relpath(root, src)
                out_dir = os.path.join(dst, rel)
                os.makedirs(out_dir, exist_ok=True)
                out_base = os.path.join(out_dir, file.rsplit(".", 1)[0])
                process_one_file(inp, out_base)


###############################################################################
# PART 7 — RUN
###############################################################################

if __name__ == "__main__":
    src_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original"
    dst_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1"
    process_all_files(src_folder, dst_folder)
# Out:
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2020-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2006-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2007-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2016-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2016-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2020-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2006-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2007-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q4-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2020-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q3-10K_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q2-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q1-10Q_cleaned.txt
# ✔ Saved MD&A → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q3-10K_cleaned.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[66], line 201
#     199 src_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original"
#     200 dst_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1"
# --> 201 process_all_files(src_folder, dst_folder)
#
# Cell In[66], line 191, in process_all_files(src, dst)
#     189 os.makedirs(out_dir, exist_ok=True)
#     190 out_base = os.path.join(out_dir, file.rsplit(".", 1)[0])
# --> 191 process_one_file(inp, out_base)
#
# Cell In[66], line 166, in process_one_file(input_file, output_base)
#     163     print("Skipping (exists):", out)
#     164     return
# --> 166 cleaned = clean_html_file(input_file)
#     167 ftype = detect_filing_type(cleaned)
#     169 mda = extract_mda(cleaned, ftype)
#
# Cell In[66], line 14, in clean_html_file(filepath)
#      11 with open(filepath, "r", encoding="utf-8", errors="ignore") as f:
#      12     raw = f.read()
# ---> 14 soup = BeautifulSoup(raw, "lxml")
#      16 # Remove tables (usually formatting-only)
#      17 for t in soup.find_all(["table", "tr", "td", "th"]):
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/__init__.py:335, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333 self.builder.initialize_soup(self)
#     334 try:
# --> 335     self._feed()
#     336     success = True
#     337     break
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/__init__.py:478, in BeautifulSoup._feed(self)
#     475 # Convert the document to Unicode.
#     476 self.builder.reset()
# --> 478 self.builder.feed(self.markup)
#     479 # Close out any unfinished strings and close all the open tags.
#     480 self.endData()
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/builder/_lxml.py:379, in LXMLTreeBuilder.feed(self, markup)
#     377     self.parser = self.parser_for(encoding)
#     378     self.parser.feed(markup)
# --> 379     self.parser.close()
#     380 except (UnicodeDecodeError, LookupError, etree.ParserError) as e:
#     381     raise ParserRejectedMarkup(e)
#
# File src/lxml/parser.pxi:1383, in lxml.etree._FeedParser.close()
#
# File src/lxml/parser.pxi:1414, in lxml.etree._FeedParser.close()
#
# File src/lxml/parsertarget.pxi:168, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src/lxml/parsertarget.pxi:156, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src/lxml/etree.pyx:334, in lxml.etree._ExceptionContext._raise_if_stored()
#
# File src/lxml/saxparser.pxi:443, in lxml.etree._handleSaxTargetStartNoNs()
#
# File src/lxml/saxparser.pxi:458, in lxml.etree._callTargetSaxStart()
#
# File src/lxml/parsertarget.pxi:94, in lxml.etree._PythonSaxParserTarget._handleSaxStart()
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/builder/_lxml.py:301, in LXMLTreeBuilderForXML.start(self, name, attrs, nsmap)
#     299 namespace, name = self._getNsTag(name)
#     300 nsprefix = self._prefix_for_namespace(namespace)
# --> 301 self.soup.handle_starttag(
#     302     name, namespace, nsprefix, attrs,
#     303     namespaces=self.active_namespace_prefixes[-1]
#     304 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/__init__.py:760, in BeautifulSoup.handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos, namespaces)
#     758     self._most_recent_element.next_element = tag
#     759 self._most_recent_element = tag
# --> 760 self.pushTag(tag)
#     761 return tag
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/__init__.py:572, in BeautifulSoup.pushTag(self, tag)
#     569         self.currentTag = self.tagStack[-1]
#     570     return self.currentTag
# --> 572 def pushTag(self, tag):
#     573     """Internal method called by handle_starttag when a tag is opened."""
#     574     #print("Push", tag.name)
#
# KeyboardInterrupt:

# %%
import os
import re
from bs4 import BeautifulSoup

###############################################################################
# PART 1 — CLEAN HTML FILINGS
###############################################################################

def clean_html_file(filepath):
    """Remove HTML, XBRL, tables, figures, boilerplate, page numbers."""
    with open(filepath, "r", encoding="utf-8", errors="ignore") as f:
        raw = f.read()

    soup = BeautifulSoup(raw, "lxml")

    # Remove tables
    for tag in soup.find_all(["table", "tr", "td", "th"]):
        tag.decompose()

    # Remove images
    for tag in soup.find_all(["figure", "img"]):
        tag.decompose()

    # Remove XBRL tags
    for tag in soup.find_all():
        if tag.name and ":" in tag.name:
            tag.decompose()

    # Remove script/style
    for t in soup(["script", "style"]):
        t.decompose()

    text = soup.get_text(separator="\n")

    # Remove page numbers on separate lines
    text = re.sub(r"\n\s*\d{1,4}\s*(?=\n)", "\n", text)

    # Remove boilerplate
    boilerplate_patterns = [
        r"United States Securities and Exchange Commission",
        r"Form\s+10-K",
        r"Form\s+10-Q",
        r"TABLE OF CONTENTS",
        r"Indicate.*?by checkmark",
        r"Yes\s*[xX]\s*No\s*[oO]",
        r"Yes\s*[oO]\s*No\s*[xX]"
    ]
    for bp in boilerplate_patterns:
        text = re.sub(bp, " ", text, flags=re.IGNORECASE | re.DOTALL)

    # Whitespace cleanup
    text = re.sub(r"[ \t]+", " ", text)
    text = re.sub(r"\n\s*\n+", "\n\n", text)

    return text.strip()


###############################################################################
# PART 2 — IMPROVED ITEM REGEX (fixes MD&A)
###############################################################################

ITEM_BOUNDARY = re.compile(
    r"(?<!\w)item[\s\u00A0\.\-–—:]*\d+[a-z]?(?!\w)",
    flags=re.IGNORECASE
)

def item_regex(n, letter=""):
    """
    More tolerant regex for item headers:
    handles ITEM 7, ITEM7, ITEM–7, ITEM 7:, ITEM 7 MANAGEMENT…
    """
    item_id = f"{n}{letter}".lower()

    pattern = (
        r"(?<!\w)"
        r"item"
        r"[\s\u00A0]*"
        r"[\.:\-–—]?"
        r"[\s\u00A0]*"
        + item_id +
        r"(?!\w)"
    )
    return pattern


TEN_K_SECTIONS = {
    "Risk_Factors": item_regex(1, "a"),
    "MD&A": item_regex(7),
    "Market_Risk": item_regex(7, "a"),
}

TEN_Q_SECTIONS = {
    "Risk_Factors": item_regex(1, "a"),
    "MD&A": item_regex(2),
    "Market_Risk": item_regex(3),
}


###############################################################################
# PART 3 — EXTRACT SECTIONS USING ITEM BOUNDARIES
###############################################################################

def extract_sections(text, patterns):
    lower = text.lower()

    # find all item boundaries
    item_positions = sorted({m.start() for m in ITEM_BOUNDARY.finditer(lower)})

    sections = {}

    for name, pattern in patterns.items():
        # --- 1. First try standard ITEM match ---
        m = re.search(pattern, lower)

        # --- 2. If MD&A is missing, fall back to keyphrase search ---
        if name == "MD&A" and not m:
            md_keywords = [
                r"management.{0,40}discussion",
                r"md&a",
                r"m d & a",
                r"mda",
            ]
            for kw in md_keywords:
                mk = re.search(kw, lower)
                if mk:
                    m = mk
                    break

        # If still not found → nothing extracted
        if not m:
            sections[name] = ""
            continue

        start = m.start()

        # find next item boundary
        next_starts = [p for p in item_positions if p > start]
        end = next_starts[0] if next_starts else len(text)

        sections[name] = text[start:end].strip()

    return sections



###############################################################################
# PART 4 — DETECT IF FILING IS 10-K OR 10-Q
###############################################################################

def detect_filing_type(text):
    t = text.lower()

    if "form 10-k" in t or ("annual report" in t and "10-k" in t):
        return "10-K"
    if "form 10-q" in t or ("quarterly report" in t and "10-q" in t):
        return "10-Q"

    # fallback: 10-Q almost always has MD&A = Item 2
    if re.search(item_regex(2), t):
        return "10-Q"

    return "10-K"


###############################################################################
# PART 5 — PROCESS ONE FILE
###############################################################################

def process_one_file(input_file, output_file_base):

    combined_path = output_file_base + "_combined.txt"

    # Skip if combined exists
    if os.path.exists(combined_path):
        print(f"Skipping (exists): {combined_path}")
        return None, None

    cleaned = clean_html_file(input_file)
    filing_type = detect_filing_type(cleaned)
    patterns = TEN_K_SECTIONS if filing_type == "10-K" else TEN_Q_SECTIONS

    sections = extract_sections(cleaned, patterns)

    # Build combined output (ONLY this file)
    with open(combined_path, "w") as combined:
        rf = sections.get("Risk_Factors", "").strip()
        if rf:
            combined.write("===== RISK FACTORS =====\n\n")
            combined.write(rf + "\n\n")

        mda = sections.get("MD&A", "").strip()
        if mda:
            combined.write("===== MD&A =====\n\n")
            combined.write(mda + "\n\n")
        else:
            print(f"⚠ MD&A NOT FOUND for {input_file}")

        mr = sections.get("Market_Risk", "").strip()
        if mr:
            combined.write("===== MARKET RISK =====\n\n")
            combined.write(mr + "\n")

    print(f"✔ Extracted & Combined → {combined_path}")

    return cleaned, sections


###############################################################################
# PART 6 — PROCESS ALL FILINGS IN A DIRECTORY
###############################################################################

def process_all_files(src_folder, dst_folder):
    for root, dirs, files in os.walk(src_folder):
        for file in files:
            if file.lower().endswith(".htm"):
                input_file = os.path.join(root, file)

                # replicate folder structure
                rel = os.path.relpath(root, src_folder)
                out_dir = os.path.join(dst_folder, rel)
                os.makedirs(out_dir, exist_ok=True)

                output_file_base = os.path.join(out_dir, file.rsplit(".", 1)[0])

                print(f"Processing: {input_file}")
                process_one_file(input_file, output_file_base)


###############################################################################
# PART 7 — RUN PIPELINE
###############################################################################

if __name__ == "__main__":
    src_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original"
    dst_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1"

    process_all_files(src_folder, dst_folder)
# Out:
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2024-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2013-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2020-Q3-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2020-Q3-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2017-Q3-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q3-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2010-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2006-Q3-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2006-Q3-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2011-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2008-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2022-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2015-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2023-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2007-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2007-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2014-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2009-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2018-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2016-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2016-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2021-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2012-Q3-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q3-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2025-Q3-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q3-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2019-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2015-Q3-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q3-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2022-Q3-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q3-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2009-Q3-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q3-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2011-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2024-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2013-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2018-Q3-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q3-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2025-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2012-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2016-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2016-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2021-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2019-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2017-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2020-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2020-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2006-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2006-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2010-Q3-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q3-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2008-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2023-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2007-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2007-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2014-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2009-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2023-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2014-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2022-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2015-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2008-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2019-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2017-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2020-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2020-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2013-Q3-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q3-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2024-Q3-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q3-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2018-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2025-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2012-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2021-Q3-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q3-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2016-Q3-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2016-Q3-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2011-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2007-Q3-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2007-Q3-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2010-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2017-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2018-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2016-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2016-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2021-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2007-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2007-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2011-Q3-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q3-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2009-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2022-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2015-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2014-Q3-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q3-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2023-Q3-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q3-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2008-Q3-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q3-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2010-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2025-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2012-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2019-Q3-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q3-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2011-Q2-10K-A.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q2-10K-A_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2024-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2013-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2025-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2025-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2021-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2021-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2023-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2023-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2022-Q2-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2022-Q2-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2019-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2019-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2020-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2020-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2017-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2017-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2018-Q2-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2018-Q2-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2024-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2024-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2023-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2023-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2019-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2019-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2025-Q2-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2025-Q2-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2024-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2024-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2020-Q2-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2020-Q2-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2018-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2018-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2021-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2021-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2022-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2022-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2022-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2022-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2023-Q2-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2023-Q2-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2018-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2018-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2021-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2021-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2019-Q2-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2019-Q2-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2025-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2025-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2024-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2024-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2017-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2017-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2020-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2020-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2021-Q2-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2021-Q2-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2019-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2019-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2020-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2020-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2017-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2017-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2023-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2023-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2022-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2022-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2018-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2018-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2024-Q2-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2024-Q2-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/DXC/DXC-2025-Q1-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2025-Q1-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2020-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2020-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2017-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2017-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2025-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2021-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2021-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2016-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2016-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2021-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2021-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2016-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2016-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2017-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2017-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2020-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2020-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2025-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2024-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2024-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2024-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2024-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2014-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2014-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2023-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2023-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2023-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2023-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2015-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2015-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2022-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2022-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2019-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2019-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2019-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2019-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2018-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2018-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2025-Q4-10Q-A.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q4-10Q-A_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2018-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2018-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2022-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2022-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2015-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2015-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2024-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2024-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2016-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2016-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2021-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2021-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2025-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2025-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2024-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2024-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2021-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2021-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2016-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2016-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2020-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2020-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2017-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2017-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2020-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2020-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2017-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2017-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2019-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2019-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2023-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2023-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2014-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2014-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2015-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2015-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2022-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2022-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2015-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2015-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2022-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2022-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2014-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2014-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2023-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2023-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2018-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2018-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2018-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2018-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CNP/CNP-2019-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2019-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2022-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2022-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2018-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2018-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2019-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2019-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2019-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2019-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2018-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2018-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2023-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2023-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2023-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2023-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2022-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2022-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2025-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2025-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2020-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2020-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2017-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2017-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2024-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2024-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2024-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2024-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2025-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2025-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2017-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2017-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2020-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2020-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2016-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2016-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2021-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2021-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2016-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2016-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2021-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2021-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2018-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2018-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2018-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2018-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2019-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2019-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2022-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2022-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2022-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2022-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2023-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2023-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2023-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2023-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2019-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2019-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2016-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2016-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/RCL/RCL-2021-Q2-10Q.htm
# ...
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CAT/CAT-2018-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2018-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CAT/CAT-2023-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2023-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CAT/CAT-2022-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2022-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CAT/CAT-2022-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2022-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CAT/CAT-2023-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2023-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CAT/CAT-2019-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2019-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CAT/CAT-2024-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2024-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CAT/CAT-2024-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2024-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CAT/CAT-2025-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2025-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CAT/CAT-2020-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2020-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CAT/CAT-2021-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2021-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CAT/CAT-2021-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2021-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CAT/CAT-2025-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2025-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CAT/CAT-2020-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2020-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CAT/CAT-2022-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2022-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CAT/CAT-2018-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2018-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CAT/CAT-2018-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2018-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CAT/CAT-2019-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2019-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CAT/CAT-2019-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2019-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CAT/CAT-2022-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2022-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CAT/CAT-2023-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2023-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CAT/CAT-2023-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CAT/CAT-2023-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/TFC/TFC-2022-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2022-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/TFC/TFC-2022-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2022-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/TFC/TFC-2023-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2023-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/TFC/TFC-2023-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2023-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/TFC/TFC-2024-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2024-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/TFC/TFC-2024-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2024-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/TFC/TFC-2020-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2020-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/TFC/TFC-2025-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2025-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/TFC/TFC-2021-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2021-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/TFC/TFC-2021-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2021-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/TFC/TFC-2020-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2020-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/TFC/TFC-2025-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2025-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/TFC/TFC-2023-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2023-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/TFC/TFC-2022-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2022-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/TFC/TFC-2022-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2022-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/TFC/TFC-2023-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2023-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/TFC/TFC-2020-Q1-10K.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2020-Q1-10K_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/TFC/TFC-2020-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2020-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/TFC/TFC-2024-Q3-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2024-Q3-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/TFC/TFC-2021-Q2-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2021-Q2-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/TFC/TFC-2025-Q4-10Q.htm
# ✔ Extracted & Combined → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/TFC/TFC-2025-Q4-10Q_combined.txt
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/TFC/TFC-2025-Q1-10K.htm
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 237
#     234 src_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original"
#     235 dst_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1"
# --> 237 process_all_files(src_folder, dst_folder)
#
# Cell In[57], line 226, in process_all_files(src_folder, dst_folder)
#     223 output_file_base = os.path.join(out_dir, file.rsplit(".", 1)[0])
#     225 print(f"Processing: {input_file}")
# --> 226 process_one_file(input_file, output_file_base)
#
# Cell In[57], line 178, in process_one_file(input_file, output_file_base)
#     175     print(f"Skipping (exists): {combined_path}")
#     176     return None, None
# --> 178 cleaned = clean_html_file(input_file)
#     179 filing_type = detect_filing_type(cleaned)
#     180 patterns = TEN_K_SECTIONS if filing_type == "10-K" else TEN_Q_SECTIONS
#
# Cell In[57], line 18, in clean_html_file(filepath)
#      16 # Remove tables
#      17 for tag in soup.find_all(["table", "tr", "td", "th"]):
# ---> 18     tag.decompose()
#      20 # Remove images
#      21 for tag in soup.find_all(["figure", "img"]):
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/element.py:1466, in Tag.decompose(self)
#    1455 def decompose(self):
#    1456     """Recursively destroys this PageElement and its children.
#    1457
#    1458     This element will be removed from the tree and wiped out; so
#    (...)
#    1464     `decomposed` property.
#    1465     """
# -> 1466     self.extract()
#    1467     i = self
#    1468     while i is not None:
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/element.py:358, in PageElement.extract(self, _self_index)
#     349 def extract(self, _self_index=None):
#     350     """Destructively rips this element out of the tree.
#     351
#     352     :param _self_index: The location of this element in its parent's
#    (...)
#     356     :return: `self`, no longer part of the tree.
#     357     """
# --> 358     if self.parent is not None:
#     359         if _self_index is None:
#     360             _self_index = self.parent.index(self)
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/element.py:1620, in Tag.__getattr__(self, tag)
#    1618 # We special case contents to avoid recursion.
#    1619 elif not tag.startswith("__") and not tag == "contents":
# -> 1620     return self.find(tag)
#    1621 raise AttributeError(
#    1622     "'%s' object has no attribute '%s'" % (self.__class__, tag))
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/element.py:2001, in Tag.find(self, name, attrs, recursive, string, **kwargs)
#    1984 """Look in the children of this PageElement and find the first
#    1985 PageElement that matches the given criteria.
#    1986
#    (...)
#    1998 :rtype: bs4.element.Tag | bs4.element.NavigableString
#    1999 """
#    2000 r = None
# -> 2001 l = self.find_all(name, attrs, recursive, string, 1, _stacklevel=3,
#    2002                   **kwargs)
#    2003 if l:
#    2004     r = l[0]
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/element.py:2030, in Tag.find_all(self, name, attrs, recursive, string, limit, **kwargs)
#    2028     generator = self.children
#    2029 _stacklevel = kwargs.pop('_stacklevel', 2)
# -> 2030 return self._find_all(name, attrs, string, limit, generator,
#    2031                       _stacklevel=_stacklevel+1, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/element.py:806, in PageElement._find_all(self, name, attrs, string, limit, generator, **kwargs)
#     804     strainer = name
#     805 else:
# --> 806     strainer = SoupStrainer(name, attrs, string, **kwargs)
#     808 if string is None and not limit and not attrs and not kwargs:
#     809     if name is True or name is None:
#     810         # Optimization to find all tags.
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/element.py:2169, in SoupStrainer.__init__(self, name, attrs, string, **kwargs)
#    2163     string = kwargs.pop('text')
#    2164     warnings.warn(
#    2165         "The 'text' argument to the SoupStrainer constructor is deprecated. Use 'string' instead.",
#    2166         DeprecationWarning, stacklevel=2
#    2167     )
# -> 2169 self.name = self._normalize_search_value(name)
#    2170 if not isinstance(attrs, dict):
#    2171     # Treat a non-dict value for attrs as a search for the 'class'
#    2172     # attribute.
#    2173     kwargs['class'] = attrs
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/element.py:2198, in SoupStrainer._normalize_search_value(self, value)
#    2195     # DEPRECATED but just in case someone is checking this.
#    2196     self.text = self.string
# -> 2198 def _normalize_search_value(self, value):
#    2199     # Leave it alone if it's a Unicode string, a callable, a
#    2200     # regular expression, a boolean, or None.
#    2201     if (isinstance(value, str) or isinstance(value, Callable) or hasattr(value, 'match')
#    2202         or isinstance(value, bool) or value is None):
#    2203         return value
#
# KeyboardInterrupt:

# %%
import os
import re
from bs4 import BeautifulSoup

###############################################################################
# PART 1 — CLEAN HTML FILINGS
###############################################################################

def clean_html_file(filepath):
    """Remove HTML, XBRL, tables, figures, checkboxes, boilerplate, page numbers."""
    with open(filepath, "r", encoding="utf-8", errors="ignore") as f:
        raw = f.read()

    soup = BeautifulSoup(raw, "lxml")

    # Remove full tables (financial statements)
    for tag in soup.find_all(["table", "tr", "td", "th"]):
        tag.decompose()

    # Remove images/figures
    for tag in soup.find_all(["figure", "img"]):
        tag.decompose()

    # Remove XBRL/Inline XBRL tags (<ix:...>, <xbrli:...>)
    for tag in soup.find_all():
        if tag.name and ":" in tag.name:
            tag.decompose()

    # Remove script and style
    for t in soup(["script", "style"]):
        t.decompose()

    text = soup.get_text(separator="\n")

    # Remove page numbers like “12” or “33” on separate lines
    text = re.sub(r"\n\s*\d{1,4}\s*(?=\n)", "\n", text)

    # Remove SEC boilerplate
    boilerplate_patterns = [
        r"United States Securities and Exchange Commission",
        r"Form\s+10-K",
        r"Form\s+10-Q",
        r"TABLE OF CONTENTS",
        r"Indicate.*?by checkmark",
        r"Yes\s*[xX]\s*No\s*[oO]",
        r"Yes\s*[oO]\s*No\s*[xX]"
    ]
    for bp in boilerplate_patterns:
        text = re.sub(bp, " ", text, flags=re.IGNORECASE | re.DOTALL)

    # Clean whitespace
    text = re.sub(r"[ \t]+", " ", text)
    text = re.sub(r"\n\s*\n+", "\n\n", text)

    return text.strip()


###############################################################################
# PART 2 — FLEXIBLE ITEM HEADER REGEX
###############################################################################

ITEM_BOUNDARY = re.compile(
    r"(?<!\w)item[\s\u00A0\.\-–—:]*\d+[a-z]?(?!\w)",
    flags=re.IGNORECASE
)

def item_regex(n, letter=""):
    item_id = f"{n}{letter}".lower()
    return (
        r"(?<!\w)"
        r"item"
        r"[\s\u00A0\.\-–—:]*"
        + item_id +
        r"(?!\w)"
    )


TEN_K_SECTIONS = {
    "Risk_Factors": item_regex(1, "a"),
    "MD&A": item_regex(7),
    "Market_Risk": item_regex(7, "a")
}

TEN_Q_SECTIONS = {
    "Risk_Factors": item_regex(1, "a"),
    "MD&A": item_regex(2),
    "Market_Risk": item_regex(3)
}


###############################################################################
# PART 3 — EXTRACT SECTIONS
###############################################################################

def extract_sections(text, patterns):
    lower = text.lower()
    item_positions = sorted({m.start() for m in ITEM_BOUNDARY.finditer(lower)})
    sections = {}

    for name, pattern in patterns.items():
        m = re.search(pattern, lower)
        if not m:
            sections[name] = ""
            continue

        start = m.start()

        next_starts = [p for p in item_positions if p > start]
        end = next_starts[0] if next_starts else len(text)

        sections[name] = text[start:end].strip()

    return sections


###############################################################################
# PART 4 — DETERMINE FILING TYPE
###############################################################################

def detect_filing_type(text):
    t = text.lower()

    if "form 10-k" in t or ("annual report" in t and "10-k" in t):
        return "10-K"
    if "form 10-q" in t or ("quarterly report" in t and "10-q" in t):
        return "10-Q"

    # fallback: 10-Q MD&A = Item 2
    if re.search(item_regex(2), t):
        return "10-Q"

    return "10-K"


###############################################################################
# PART 5 — PROCESS ONE FILE
###############################################################################

def process_one_file(input_file, output_file_base):

    # Skip if cleaned already exists
    cleaned_path = output_file_base + "_cleaned.txt"
    if os.path.exists(cleaned_path):
        print(f"Skipping (already exists): {cleaned_path}")
        return None, None

    cleaned = clean_html_file(input_file)

    with open(cleaned_path, "w") as f:
        f.write(cleaned)

    filing_type = detect_filing_type(cleaned)
    patterns = TEN_K_SECTIONS if filing_type == "10-K" else TEN_Q_SECTIONS

    sections = extract_sections(cleaned, patterns)

    # Save each extracted section
    section_dir = output_file_base + "_sections"
    os.makedirs(section_dir, exist_ok=True)

    for name, content in sections.items():
        sec_path = os.path.join(section_dir, f"{name}.txt")
        with open(sec_path, "w") as f:
            f.write(content)

    # -------------------------------------------
    # BUILD COMBINED: just append the three parts
    # -------------------------------------------
    combined_path = output_file_base + "_sections_combined.txt"
    with open(combined_path, "w") as combined:
        rf = sections.get("Risk_Factors", "").strip()
        if rf:
            combined.write(rf + "\n\n")

        mda = sections.get("MD&A", "").strip()
        if mda:
            combined.write(mda + "\n\n")

        mr = sections.get("Market_Risk", "").strip()
        if mr:
            combined.write(mr)

    return cleaned, sections


###############################################################################
# PART 6 — WALK AND PROCESS ALL FILINGS
###############################################################################

def process_all_files(src_folder, dst_folder):
    for root, dirs, files in os.walk(src_folder):
        for file in files:
            if file.lower().endswith(".htm"):
                input_file = os.path.join(root, file)

                rel = os.path.relpath(root, src_folder)
                out_dir = os.path.join(dst_folder, rel)
                os.makedirs(out_dir, exist_ok=True)

                output_file_base = os.path.join(out_dir, file.rsplit(".", 1)[0])

                print(f"Processing: {input_file}")
                process_one_file(input_file, output_file_base)


###############################################################################
# PART 7 — RUN
###############################################################################

if __name__ == "__main__":
    src_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original"
    dst_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1"

    process_all_files(src_folder, dst_folder)
# Out:
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2024-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2013-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2020-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2017-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2010-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2006-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2011-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2008-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2022-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2015-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2023-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2007-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2014-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2009-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2018-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2016-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2021-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2012-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2025-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2019-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2015-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2022-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2009-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2011-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2024-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2013-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2018-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2025-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2012-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2016-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2021-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2019-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2017-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2020-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2006-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2010-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2008-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2023-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2007-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2014-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2009-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2023-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2014-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2022-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2015-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2008-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2019-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2017-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2020-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2013-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2024-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2018-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2025-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2012-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2021-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2016-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2011-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2007-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2010-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2017-Q2-10Q.htm
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 214
#     211 src_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original"
#     212 dst_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1"
# --> 214 process_all_files(src_folder, dst_folder)
#
# Cell In[45], line 203, in process_all_files(src_folder, dst_folder)
#     200 output_file_base = os.path.join(out_dir, file.rsplit(".", 1)[0])
#     202 print(f"Processing: {input_file}")
# --> 203 process_one_file(input_file, output_file_base)
#
# Cell In[45], line 147, in process_one_file(input_file, output_file_base)
#     144     print(f"Skipping (already exists): {cleaned_path}")
#     145     return None, None
# --> 147 cleaned = clean_html_file(input_file)
#     149 with open(cleaned_path, "w") as f:
#     150     f.write(cleaned)
#
# Cell In[45], line 14, in clean_html_file(filepath)
#      11 with open(filepath, "r", encoding="utf-8", errors="ignore") as f:
#      12     raw = f.read()
# ---> 14 soup = BeautifulSoup(raw, "lxml")
#      16 # Remove full tables (financial statements)
#      17 for tag in soup.find_all(["table", "tr", "td", "th"]):
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/__init__.py:335, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333 self.builder.initialize_soup(self)
#     334 try:
# --> 335     self._feed()
#     336     success = True
#     337     break
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/__init__.py:478, in BeautifulSoup._feed(self)
#     475 # Convert the document to Unicode.
#     476 self.builder.reset()
# --> 478 self.builder.feed(self.markup)
#     479 # Close out any unfinished strings and close all the open tags.
#     480 self.endData()
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/builder/_lxml.py:379, in LXMLTreeBuilder.feed(self, markup)
#     377     self.parser = self.parser_for(encoding)
#     378     self.parser.feed(markup)
# --> 379     self.parser.close()
#     380 except (UnicodeDecodeError, LookupError, etree.ParserError) as e:
#     381     raise ParserRejectedMarkup(e)
#
# File src/lxml/parser.pxi:1383, in lxml.etree._FeedParser.close()
#
# File src/lxml/parser.pxi:1414, in lxml.etree._FeedParser.close()
#
# File src/lxml/parsertarget.pxi:168, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src/lxml/parsertarget.pxi:156, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src/lxml/etree.pyx:334, in lxml.etree._ExceptionContext._raise_if_stored()
#
# File src/lxml/saxparser.pxi:443, in lxml.etree._handleSaxTargetStartNoNs()
#
# File src/lxml/saxparser.pxi:458, in lxml.etree._callTargetSaxStart()
#
# File src/lxml/parsertarget.pxi:94, in lxml.etree._PythonSaxParserTarget._handleSaxStart()
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/builder/_lxml.py:289, in LXMLTreeBuilderForXML.start(self, name, attrs, nsmap)
#     285 # Namespaces are in play. Find any attributes that came in
#     286 # from lxml with namespaces attached to their names, and
#     287 # turn then into NamespacedAttribute objects.
#     288 new_attrs = {}
# --> 289 for attr, value in list(attrs.items()):
#     290     namespace, attr = self._getNsTag(attr)
#     291     if namespace is None:
#
# KeyboardInterrupt:

# %%
import os
import re
from bs4 import BeautifulSoup

###############################################################################
# PART 1 — CLEAN HTML FILINGS
###############################################################################

def clean_html_file(filepath):
    """Remove HTML, XBRL, tables, figures, checkboxes, boilerplate, page numbers."""
    with open(filepath, "r", encoding="utf-8", errors="ignore") as f:
        raw = f.read()

    soup = BeautifulSoup(raw, "lxml")

    # Remove full tables (financial statements)
    for tag in soup.find_all(["table", "tr", "td", "th"]):
        tag.decompose()

    # Remove images/figures
    for tag in soup.find_all(["figure", "img"]):
        tag.decompose()

    # Remove XBRL/Inline XBRL tags (<ix:...>, <xbrli:...>)
    for tag in soup.find_all():
        if tag.name and ":" in tag.name:
            tag.decompose()

    # Remove script and style
    for t in soup(["script", "style"]):
        t.decompose()

    text = soup.get_text(separator="\n")

    # Remove page numbers (more robust)
    text = re.sub(r"\n\s*\d{1,4}\s*(?=\n)", "\n", text)

    # Remove SEC boilerplate
    boilerplate_patterns = [
        r"United States Securities and Exchange Commission",
        r"Form\s+10-K",
        r"Form\s+10-Q",
        r"TABLE OF CONTENTS",
        r"Indicate.*?by checkmark",
        r"Yes\s*[xX]\s*No\s*[oO]",
        r"Yes\s*[oO]\s*No\s*[xX]"
    ]
    for bp in boilerplate_patterns:
        text = re.sub(bp, " ", text, flags=re.IGNORECASE | re.DOTALL)

    # Clean whitespace
    text = re.sub(r"[ \t]+", " ", text)
    text = re.sub(r"\n\s*\n+", "\n\n", text)

    return text.strip()


###############################################################################
# PART 2 — FLEXIBLE ITEM HEADER REGEX
###############################################################################

ITEM_BOUNDARY = re.compile(
    r"(?<!\w)item[\s\u00A0\.\-–—:]*\d+[a-z]?(?!\w)",
    flags=re.IGNORECASE
)

def item_regex(n, letter=""):
    item_id = f"{n}{letter}".lower()
    pattern = (
        r"(?<!\w)"
        r"item"
        r"[\s\u00A0\.\-–—:]*"
        + item_id +
        r"(?!\w)"
    )
    return pattern


TEN_K_SECTIONS = {
    "Risk_Factors": item_regex(1, "a"),
    "MD&A": item_regex(7),
    "Market_Risk": item_regex(7, "a")
}

TEN_Q_SECTIONS = {
    "Risk_Factors": item_regex(1, "a"),
    "MD&A": item_regex(2),
    "Market_Risk": item_regex(3)
}

###############################################################################
# PART 3 — EXTRACT SECTIONS
###############################################################################

def extract_sections(text, patterns):
    lower = text.lower()

    item_positions = [m.start() for m in ITEM_BOUNDARY.finditer(lower)]
    item_positions = sorted(set(item_positions))

    sections = {}

    for name, pattern in patterns.items():
        m = re.search(pattern, lower)
        if not m:
            sections[name] = ""
            continue

        start = m.start()
        next_starts = [p for p in item_positions if p > start]
        end = next_starts[0] if next_starts else len(text)

        sections[name] = text[start:end].strip()

    return sections


###############################################################################
# PART 4 — DETERMINE FILING TYPE (10-K or 10-Q)
###############################################################################

def detect_filing_type(text):
    t = text.lower()

    if "form 10-k" in t or ("annual report" in t and "10-k" in t):
        return "10-K"
    if "form 10-q" in t or ("quarterly report" in t and "10-q" in t):
        return "10-Q"

    # fallback: 10-Q MD&A = Item 2
    if re.search(item_regex(2), t):
        return "10-Q"

    return "10-K"


###############################################################################
# PART 5 — PROCESS ONE FILE
###############################################################################

def process_one_file(input_file, output_file_base):

    # ---------------------------------------------------
    # Skip if output already exists
    # ---------------------------------------------------
    cleaned_path = output_file_base + "_cleaned.txt"
    if os.path.exists(cleaned_path):
        print(f"Skipping (already exists): {cleaned_path}")
        return None, None
    # ---------------------------------------------------

    cleaned = clean_html_file(input_file)

    with open(cleaned_path, "w") as f:
        f.write(cleaned)

    filing_type = detect_filing_type(cleaned)
    patterns = TEN_K_SECTIONS if filing_type == "10-K" else TEN_Q_SECTIONS

    sections = extract_sections(cleaned, patterns)

    section_dir = output_file_base + "_sections"
    os.makedirs(section_dir, exist_ok=True)

    combined_path = output_file_base + "_sections_combined.txt"
    with open(combined_path, "w") as combined:
        for name, content in sections.items():
            sec_path = os.path.join(section_dir, f"{name}.txt")
            with open(sec_path, "w") as f:
                f.write(content)
            combined.write(f"\n\n===== {name} =====\n\n")
            combined.write(content)

    return cleaned, sections


###############################################################################
# PART 6 — WALK DIRECTORY AND PROCESS ALL FILINGS
###############################################################################

def process_all_files(src_folder, dst_folder):
    for root, dirs, files in os.walk(src_folder):
        for file in files:
            if file.lower().endswith(".htm"):
                input_file = os.path.join(root, file)

                # mirror directory structure
                rel = os.path.relpath(root, src_folder)
                out_dir = os.path.join(dst_folder, rel)
                os.makedirs(out_dir, exist_ok=True)

                output_file_base = os.path.join(out_dir, file.rsplit(".", 1)[0])

                print(f"Processing: {input_file}")
                process_one_file(input_file, output_file_base)


###############################################################################
# PART 7 — RUN
###############################################################################

if __name__ == "__main__":
    src_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original"
    dst_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1"

    process_all_files(src_folder, dst_folder)
# Out:
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2024-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2013-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2020-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2017-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2010-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2006-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2011-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2008-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2022-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2015-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2023-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2007-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2014-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2009-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2018-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2016-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2021-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2012-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2025-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2019-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2015-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2022-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2009-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2011-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2024-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2013-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2018-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2025-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2012-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2016-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2021-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2019-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2017-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2020-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2006-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2010-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2008-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2023-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2007-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2014-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2009-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2023-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2014-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2022-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2015-Q2-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2008-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2019-Q4-10Q.htm
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 208
#     205 src_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original"
#     206 dst_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1"
# --> 208 process_all_files(src_folder, dst_folder)
#
# Cell In[44], line 197, in process_all_files(src_folder, dst_folder)
#     194 output_file_base = os.path.join(out_dir, file.rsplit(".", 1)[0])
#     196 print(f"Processing: {input_file}")
# --> 197 process_one_file(input_file, output_file_base)
#
# Cell In[44], line 152, in process_one_file(input_file, output_file_base)
#     151 def process_one_file(input_file, output_file_base):
# --> 152     cleaned = clean_html_file(input_file)
#     154     # Save cleaned full text
#     155     with open(output_file_base + "_cleaned.txt", "w") as f:
#
# Cell In[44], line 14, in clean_html_file(filepath)
#      11 with open(filepath, "r", encoding="utf-8", errors="ignore") as f:
#      12     raw = f.read()
# ---> 14 soup = BeautifulSoup(raw, "lxml")
#      16 # Remove full tables (financial statements)
#      17 for tag in soup.find_all(["table", "tr", "td", "th"]):
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/__init__.py:335, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333 self.builder.initialize_soup(self)
#     334 try:
# --> 335     self._feed()
#     336     success = True
#     337     break
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/__init__.py:478, in BeautifulSoup._feed(self)
#     475 # Convert the document to Unicode.
#     476 self.builder.reset()
# --> 478 self.builder.feed(self.markup)
#     479 # Close out any unfinished strings and close all the open tags.
#     480 self.endData()
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/builder/_lxml.py:379, in LXMLTreeBuilder.feed(self, markup)
#     377     self.parser = self.parser_for(encoding)
#     378     self.parser.feed(markup)
# --> 379     self.parser.close()
#     380 except (UnicodeDecodeError, LookupError, etree.ParserError) as e:
#     381     raise ParserRejectedMarkup(e)
#
# File src/lxml/parser.pxi:1383, in lxml.etree._FeedParser.close()
#
# File src/lxml/parser.pxi:1414, in lxml.etree._FeedParser.close()
#
# File src/lxml/parsertarget.pxi:168, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src/lxml/parsertarget.pxi:156, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src/lxml/etree.pyx:334, in lxml.etree._ExceptionContext._raise_if_stored()
#
# File src/lxml/saxparser.pxi:443, in lxml.etree._handleSaxTargetStartNoNs()
#
# File src/lxml/saxparser.pxi:458, in lxml.etree._callTargetSaxStart()
#
# File src/lxml/parsertarget.pxi:94, in lxml.etree._PythonSaxParserTarget._handleSaxStart()
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/builder/_lxml.py:243, in LXMLTreeBuilderForXML.start(self, name, attrs, nsmap)
#     240 def close(self):
#     241     self.nsmaps = [self.DEFAULT_NSMAPS_INVERTED]
# --> 243 def start(self, name, attrs, nsmap={}):
#     244     # Make sure attrs is a mutable dict--lxml may send an immutable dictproxy.
#     245     attrs = dict(attrs)
#     246     nsprefix = None
#
# KeyboardInterrupt:

# %%
import os
import re
from bs4 import BeautifulSoup

###############################################################################
# PART 1 — CLEAN HTML FILINGS
###############################################################################

def clean_html_file(filepath):
    """Remove HTML, XBRL, tables, figures, checkboxes, and SEC boilerplate."""
    with open(filepath, "r", encoding="utf-8", errors="ignore") as f:
        raw = f.read()

    soup = BeautifulSoup(raw, "lxml")

    # Remove tables + their contents
    for tag in soup.find_all(["table", "tr", "td", "th"]):
        tag.decompose()

    # Remove images/figures
    for tag in soup.find_all(["figure", "img"]):
        tag.decompose()

    # Remove XBRL/Inline XBRL tags (<ix:...>, <xbrl:...>, etc.)
    for tag in soup.find_all():
        if tag.name and ":" in tag.name:
            tag.decompose()

    # Remove script/style
    for t in soup(["script", "style"]):
        t.decompose()

    text = soup.get_text(separator="\n")

    # Drop SEC boilerplate/checkboxes
    boilerplate_patterns = [
        r"United States Securities and Exchange Commission",
        r"Form\s+10-K",
        r"Form\s+10-Q",
        r"TABLE OF CONTENTS",
        r"Indicate.*?by checkmark",
        r"Yes\s*[xX]\s*No\s*[oO]",
        r"Yes\s*[oO]\s*No\s*[xX]"
    ]
    for bp in boilerplate_patterns:
        text = re.sub(bp, " ", text, flags=re.IGNORECASE | re.DOTALL)

    # Normalize whitespace
    text = re.sub(r"\n\s*\n+", "\n\n", text)
    text = re.sub(r"[ \t]+", " ", text)

    return text.strip()


###############################################################################
# PART 2 — REGEX FOR ITEM HEADERS (COVERS ALL VARIATIONS)
###############################################################################

def item_regex(n, letter=""):
    """
    Build a flexible pattern matching:
       ITEM 7
       Item 7.
       ITEM 7A —
       Item 7 – MD&A
       ITEM 7A. 
       Item\xa07
    """
    item_id = f"{n}{letter}".lower()

    pattern = (
        r"item[\s\u00A0\.\-–—:]*" +   # ITEM or Item + punctuation/nbsp
        item_id +
        r"[\s\u00A0\.\-–—:]"         # terminating punctuation or space
    )
    return pattern


# Important sections to extract
TEN_K_SECTIONS = {
    "Business": item_regex(1),
    "Risk_Factors": item_regex(1, "a"),
    "MD&A": item_regex(7),
    "Market_Risk": item_regex(7, "a"),
    "Financial_Statements": item_regex(8)
}

TEN_Q_SECTIONS = {
    "Risk_Factors": item_regex(1, "a"),
    "MD&A": item_regex(2),
    "Market_Risk": item_regex(3),
    "Controls_Procedures": item_regex(4)
}


###############################################################################
# PART 3 — EXTRACT SECTIONS BASED ON ITEM HEADINGS
###############################################################################

def extract_sections(text, patterns):
    """Extract sections from cleaned text using flexible ITEM regex."""
    sections = {}
    lower = text.lower()

    # Find all item positions to determine boundaries
    item_positions = []
    for match in re.finditer(r"item[\s\u00A0\.\-–—:]*\d+[a-z]?", lower):
        item_positions.append(match.start())

    item_positions = sorted(set(item_positions))

    for name, pattern in patterns.items():
        m = re.search(pattern, lower)
        if not m:
            sections[name] = ""
            continue

        start = m.start()

        # Find next item after this one
        next_starts = [p for p in item_positions if p > start]
        end = next_starts[0] if next_starts else len(text)

        sections[name] = text[start:end].strip()

    return sections


###############################################################################
# PART 4 — DETERMINE IF FILING IS 10-K OR 10-Q
###############################################################################

def detect_filing_type(text):
    """Return '10-K' or '10-Q' based on keywords in the cleaned text."""
    t = text.lower()

    if "form 10-k" in t:
        return "10-K"
    if "annual report" in t and "10-k" in t:
        return "10-K"

    if "form 10-q" in t:
        return "10-Q"
    if "quarterly report" in t and "10-q" in t:
        return "10-Q"

    # fallback: Q filings have Item 2 MD&A instead of Item 7
    if re.search(item_regex(2), t):
        return "10-Q"

    return "10-K"   # default


###############################################################################
# PART 5 — PROCESS A SINGLE FILE
###############################################################################

def process_one_file(input_file, output_file_base):
    cleaned = clean_html_file(input_file)

    with open(output_file_base + "_cleaned.txt", "w") as f:
        f.write(cleaned)

    filing_type = detect_filing_type(cleaned)

    if filing_type == "10-K":
        patterns = TEN_K_SECTIONS
    else:
        patterns = TEN_Q_SECTIONS

    sections = extract_sections(cleaned, patterns)

    # Save each section
    os.makedirs(output_file_base + "_sections", exist_ok=True)
    combined_path = output_file_base + "_sections_combined.txt"

    with open(combined_path, "w") as combined:
        for name, content in sections.items():
            sec_path = os.path.join(output_file_base + "_sections", f"{name}.txt")
            with open(sec_path, "w") as f:
                f.write(content)

            combined.write(f"\n\n===== {name} =====\n\n")
            combined.write(content)

    return cleaned, sections


###############################################################################
# PART 6 — WALK ALL SUBFOLDERS AND PROCESS EVERYTHING
###############################################################################

def process_all_files(src_folder, dst_folder):
    for root, dirs, files in os.walk(src_folder):
        for file in files:
            if file.lower().endswith(".htm"):
                input_file = os.path.join(root, file)

                # Mirror directory structure
                rel = os.path.relpath(root, src_folder)
                out_dir = os.path.join(dst_folder, rel)
                os.makedirs(out_dir, exist_ok=True)

                output_file_base = os.path.join(out_dir, file.rsplit(".", 1)[0])

                print(f"Processing: {input_file}")
                process_one_file(input_file, output_file_base)


###############################################################################
# PART 7 — RUN THE PIPELINE (YOUR PATHS)
###############################################################################

if __name__ == "__main__":
    src_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original"
    dst_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1"

    process_all_files(src_folder, dst_folder)
# Out:
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2024-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2013-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2020-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2017-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2010-Q4-10Q.htm
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 218
#     215 src_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original"
#     216 dst_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1"
# --> 218 process_all_files(src_folder, dst_folder)
#
# Cell In[39], line 207, in process_all_files(src_folder, dst_folder)
#     204 output_file_base = os.path.join(out_dir, file.rsplit(".", 1)[0])
#     206 print(f"Processing: {input_file}")
# --> 207 process_one_file(input_file, output_file_base)
#
# Cell In[39], line 159, in process_one_file(input_file, output_file_base)
#     158 def process_one_file(input_file, output_file_base):
# --> 159     cleaned = clean_html_file(input_file)
#     161     with open(output_file_base + "_cleaned.txt", "w") as f:
#     162         f.write(cleaned)
#
# Cell In[39], line 18, in clean_html_file(filepath)
#      16 # Remove tables + their contents
#      17 for tag in soup.find_all(["table", "tr", "td", "th"]):
# ---> 18     tag.decompose()
#      20 # Remove images/figures
#      21 for tag in soup.find_all(["figure", "img"]):
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/element.py:1466, in Tag.decompose(self)
#    1455 def decompose(self):
#    1456     """Recursively destroys this PageElement and its children.
#    1457
#    1458     This element will be removed from the tree and wiped out; so
#    (...)
#    1464     `decomposed` property.
#    1465     """
# -> 1466     self.extract()
#    1467     i = self
#    1468     while i is not None:
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/element.py:366, in PageElement.extract(self, _self_index)
#     361     del self.parent.contents[_self_index]
#     363 #Find the two elements that would be next to each other if
#     364 #this element (and any children) hadn't been parsed. Connect
#     365 #the two.
# --> 366 last_child = self._last_descendant()
#     367 next_element = last_child.next_element
#     369 if (self.previous_element is not None and
#     370     self.previous_element is not next_element):
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/element.py:387, in PageElement._last_descendant(self, is_initialized, accept_self)
#     384     self.previous_sibling = self.next_sibling = None
#     385     return self
# --> 387 def _last_descendant(self, is_initialized=True, accept_self=True):
#     388     """Finds the last element beneath this object to be parsed.
#     389
#     390     :param is_initialized: Has `setup` been called on this PageElement
#     391         yet?
#     392     :param accept_self: Is `self` an acceptable answer to the question?
#     393     """
#     394     if is_initialized and self.next_sibling is not None:
#
# KeyboardInterrupt:

# %%
# soem sort of section action
import os
import re
from bs4 import BeautifulSoup

# ============================================================
#                HELPERS TO LOAD & CLEAN HTML
# ============================================================

def load_html(path):
    """Read the raw HTML file."""
    with open(path, "r", encoding="utf-8", errors="ignore") as f:
        return f.read()

def remove_sec_header(text):
    """
    Remove boilerplate SEC header that usually appears at the top:
    'UNITED STATES SECURITIES AND EXCHANGE COMMISSION... checkboxes...'
    """
    pattern = r"UNITED STATES SECURITIES AND EXCHANGE COMMISSION(.+?)(Table of Contents|PART I|Item 1\.?)"
    cleaned = re.sub(pattern, r"\2", text, flags=re.DOTALL | re.IGNORECASE)
    return cleaned


def remove_tables(soup):
    """Remove <table> elements entirely."""
    for table in soup.find_all("table"):
        table.decompose()
    return soup


def html_to_clean_text(html):
    """
    Convert HTML into clean plain text:
    - remove scripts, styles
    - remove tables
    - collapse whitespace
    """
    soup = BeautifulSoup(html, "html.parser")

    # Remove scripts and styles
    for tag in soup(["script", "style"]):
        tag.decompose()

    # Remove tables
    soup = remove_tables(soup)

    # Get text
    text = soup.get_text(separator="\n")

    # Normalize whitespace
    text = re.sub(r"\n\s*\n+", "\n\n", text)
    text = re.sub(r"[ \t]+", " ", text)
    text = text.strip()

    return text


# ============================================================
#                 SECTION EXTRACTION (Items)
# ============================================================

# Regex for typical 10-K and 10-Q section headings
SECTION_PATTERNS = {
    "Item 1": r"item\s*1[^A-Za-z0-9]",
    "Item 1A Risk Factors": r"item\s*1a",
    "Item 2 MD&A": r"item\s*2[^0-9a-z]",
    "Item 3": r"item\s*3[^0-9a-z]",
    "Item 4": r"item\s*4[^0-9a-z]",
    "Item 5": r"item\s*5[^0-9a-z]",
    "Item 6": r"item\s*6[^0-9a-z]",
    "Item 7 MD&A (10-K)": r"item\s*7[^0-9a-z]",
    "Item 7A": r"item\s*7a",
    "Item 8 Financial Statements": r"item\s*8[^0-9a-z]",
    "Item 9": r"item\s*9[^0-9a-z]",
}

def extract_sections(text):
    """
    Extract key 10-K / 10-Q sections into a dict:
    { "Item 2 MD&A": "...", "Item 1A Risk Factors": "...", ... }
    """
    lower_text = text.lower()
    positions = []

    # Find occurrences of headings
    for sec_name, pattern in SECTION_PATTERNS.items():
        for match in re.finditer(pattern, lower_text, flags=re.IGNORECASE):
            positions.append((match.start(), sec_name))

    if not positions:
        return {}

    # Sort by text order
    positions.sort()

    # Extract text chunks between headings
    sections = {}
    for idx, (start_pos, sec_name) in enumerate(positions):
        end_pos = positions[idx + 1][0] if idx + 1 < len(positions) else len(text)
        section_text = text[start_pos:end_pos].strip()

        # Save non-empty
        if len(section_text) > 20:
            sections[sec_name] = section_text

    return sections


# ============================================================
#                    WRITE OUTPUT FILES
# ============================================================

def write_clean_text(dst_path, text):
    """Write the cleaned text."""
    with open(dst_path, "w", encoding="utf-8") as f:
        f.write(text)

def write_section_files(base_folder, sections):
    """Write each extracted section to a separate .txt file."""
    section_dir = os.path.join(base_folder, "sections")
    os.makedirs(section_dir, exist_ok=True)

    for sec_name, content in sections.items():
        safe_name = sec_name.replace(" ", "_").replace("/", "_")
        path = os.path.join(section_dir, f"{safe_name}.txt")
        with open(path, "w", encoding="utf-8") as f:
            f.write(content)


# ============================================================
#                  PIPELINE FOR A SINGLE FILE
# ============================================================

def process_file(src_file, dst_folder):
    """
    End-to-end pipeline for one HTML file:
      1. Load HTML
      2. Convert to clean text
      3. Remove SEC header
      4. Extract sections
      5. Save outputs
    """

    html = load_html(src_file)
    text = html_to_clean_text(html)
    text = remove_sec_header(text)

    # Output file
    filename = os.path.basename(src_file).replace(".htm", "_cleaned.txt")
    dst_file = os.path.join(dst_folder, filename)

    # Save cleaned full text
    write_clean_text(dst_file, text)

    # Extract sections (Item 1A, MD&A, etc.)
    sections = extract_sections(text)
    write_section_files(dst_folder, sections)


# ============================================================
#             RUN ON ALL FILINGS IN A FOLDER
# ============================================================

def process_all_files(src_folder, dst_folder):
    """
    Walk the source directory and process every .htm file.
    Maintain subfolder structure.
    """
    for root, dirs, files in os.walk(src_folder):
        for file in files:
            if file.lower().endswith(".htm"):
                src_path = os.path.join(root, file)

                # Mirror directory structure under dst/
                relative = os.path.relpath(root, src_folder)
                new_dst = os.path.join(dst_folder, relative)
                os.makedirs(new_dst, exist_ok=True)

                print(f"Processing: {src_path}")
                process_file(src_path, new_dst)


# ============================================================
#                RUN PIPELINE WITH YOUR PATHS
# ============================================================

if __name__ == "__main__":
    # YOUR FOLDER PATHS (✓ Correct for your Mac)
    src_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original"
    dst_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1"

    process_all_files(src_folder, dst_folder)
# Out:
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2024-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2013-Q1-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2020-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2017-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2010-Q4-10Q.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2006-Q3-10K.htm
# Processing: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2011-Q2-10Q.htm
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 192
#     189 src_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original"
#     190 dst_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1"
# --> 192 process_all_files(src_folder, dst_folder)
#
# Cell In[34], line 180, in process_all_files(src_folder, dst_folder)
#     177 os.makedirs(new_dst, exist_ok=True)
#     179 print(f"Processing: {src_path}")
# --> 180 process_file(src_path, new_dst)
#
# Cell In[34], line 145, in process_file(src_file, dst_folder)
#     135 """
#     136 End-to-end pipeline for one HTML file:
#     137   1. Load HTML
#    (...)
#     141   5. Save outputs
#     142 """
#     144 html = load_html(src_file)
# --> 145 text = html_to_clean_text(html)
#     146 text = remove_sec_header(text)
#     148 # Output file
#
# Cell In[34], line 38, in html_to_clean_text(html)
#      31 def html_to_clean_text(html):
#      32     """
#      33     Convert HTML into clean plain text:
#      34     - remove scripts, styles
#      35     - remove tables
#      36     - collapse whitespace
#      37     """
# ---> 38     soup = BeautifulSoup(html, "html.parser")
#      40     # Remove scripts and styles
#      41     for tag in soup(["script", "style"]):
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/__init__.py:335, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333 self.builder.initialize_soup(self)
#     334 try:
# --> 335     self._feed()
#     336     success = True
#     337     break
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/__init__.py:478, in BeautifulSoup._feed(self)
#     475 # Convert the document to Unicode.
#     476 self.builder.reset()
# --> 478 self.builder.feed(self.markup)
#     479 # Close out any unfinished strings and close all the open tags.
#     480 self.endData()
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/builder/_htmlparser.py:380, in HTMLParserTreeBuilder.feed(self, markup)
#     378 parser.soup = self.soup
#     379 try:
# --> 380     parser.feed(markup)
#     381 except AssertionError as e:
#     382     # html.parser raises AssertionError in rare cases to
#     383     # indicate a fatal problem with the markup, especially
#     384     # when there's an error in the doctype declaration.
#     385     raise ParserRejectedMarkup(e)
#
# File /opt/anaconda3/lib/python3.11/html/parser.py:110, in HTMLParser.feed(self, data)
#     104 r"""Feed data to the parser.
#     105
#     106 Call this as often as you want, with as little or as much text
#     107 as you want (may include '\n').
#     108 """
#     109 self.rawdata = self.rawdata + data
# --> 110 self.goahead(0)
#
# File /opt/anaconda3/lib/python3.11/html/parser.py:170, in HTMLParser.goahead(self, end)
#     168 if startswith('<', i):
#     169     if starttagopen.match(rawdata, i): # < + letter
# --> 170         k = self.parse_starttag(i)
#     171     elif startswith("</", i):
#     172         k = self.parse_endtag(i)
#
# File /opt/anaconda3/lib/python3.11/html/parser.py:337, in HTMLParser.parse_starttag(self, i)
#     335     self.handle_startendtag(tag, attrs)
#     336 else:
# --> 337     self.handle_starttag(tag, attrs)
#     338     if tag in self.CDATA_CONTENT_ELEMENTS:
#     339         self.set_cdata_mode(tag)
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/builder/_htmlparser.py:137, in BeautifulSoupHTMLParser.handle_starttag(self, name, attrs, handle_empty_element)
#     135 #print("START", name)
#     136 sourceline, sourcepos = self.getpos()
# --> 137 tag = self.soup.handle_starttag(
#     138     name, None, None, attr_dict, sourceline=sourceline,
#     139     sourcepos=sourcepos
#     140 )
#     141 if tag and tag.is_empty_element and handle_empty_element:
#     142     # Unlike other parsers, html.parser doesn't send separate end tag
#     143     # events for empty-element tags. (It's handled in
#    (...)
#     149     # don't want handle_endtag() to cross off any previous end
#     150     # events for tags of this name.
#     151     self.handle_endtag(name, check_already_closed=False)
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/__init__.py:749, in BeautifulSoup.handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos, namespaces)
#     744 if (self.parse_only and len(self.tagStack) <= 1
#     745     and (self.parse_only.text
#     746          or not self.parse_only.search_tag(name, attrs))):
#     747     return None
# --> 749 tag = self.element_classes.get(Tag, Tag)(
#     750     self, self.builder, name, namespace, nsprefix, attrs,
#     751     self.currentTag, self._most_recent_element,
#     752     sourceline=sourceline, sourcepos=sourcepos,
#     753     namespaces=namespaces
#     754 )
#     755 if tag is None:
#     756     return tag
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/element.py:1262, in Tag.__init__(self, parser, builder, name, namespace, prefix, attrs, parent, previous, is_xml, sourceline, sourcepos, can_be_empty_element, cdata_list_attributes, preserve_whitespace_tags, interesting_string_types, namespaces)
#    1260 elif attrs:
#    1261     if builder is not None and builder.cdata_list_attributes:
# -> 1262         attrs = builder._replace_cdata_list_attribute_values(
#    1263             self.name, attrs)
#    1264     else:
#    1265         attrs = dict(attrs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/builder/__init__.py:295, in TreeBuilder._replace_cdata_list_attribute_values(self, tag_name, attrs)
#     284     """Set up any substitutions that will need to be performed on
#     285     a `Tag` when it's output as a string.
#     286
#    (...)
#     291     :return: Whether or not a substitution was performed.
#     292     """
#     293     return False
# --> 295 def _replace_cdata_list_attribute_values(self, tag_name, attrs):
#     296     """When an attribute value is associated with a tag that can
#     297     have multiple values for that attribute, convert the string
#     298     value to a list of strings.
#    (...)
#     306        Any appropriate attribute values will be modified in place.
#     307     """
#     308     if not attrs:
#
# KeyboardInterrupt:

# %%
# strips text, but still has table of contents

import os
import re
from bs4 import BeautifulSoup

# ================================================================
# 1. Clean HTML → text (keep narrative, drop HTML/XBRL/tables)
# ================================================================
def clean_html_text(html):
    soup = BeautifulSoup(html, "lxml")

    # 1. Remove all tables
    for t in soup.find_all("table"):
        t.decompose()

    # 2. Remove XBRL tags
    for tag in soup.find_all(['xbrl', 'ix:nonfraction', 'ix:nonNumeric']):
        tag.decompose()

    # 3. Remove scripts/styles
    for bad in soup(["script", "style"]):
        bad.decompose()

    # 4. Extract text
    text = soup.get_text(separator=" ")

    # 5. Normalize whitespace
    text = re.sub(r'\s+', ' ', text)

    return text.strip()

# ================================================================
# 2. SAFE removal of Item 1 – Financial Statements section only
#    → Works for 10-Q and 10-K
# ================================================================
def remove_financials(text):
    """
    Remove the Financial Statements section (Item 1) safely.
    Only removes if both start and end markers exist and in order.
    """

    # Patterns for start and end boundaries
    start_pat = r"ITEM\s*1[^A-Za-z0-9]{0,6}(FINANCIAL STATEMENTS|FINANCIAL INFORMATION)"
    end_pat   = r"ITEM\s*2[^A-Za-z0-9]{0,6}(MANAGEMENT|MD&A)"

    start = re.search(start_pat, text, flags=re.IGNORECASE)
    end   = re.search(end_pat, text, flags=re.IGNORECASE)

    # Only cut if both found in correct order
    if start and end and start.start() < end.start():
        before = text[:start.start()]
        after = text[end.start():]
        return before + "\n\n" + after

    return text

# ================================================================
# 3. Postprocessing cleanup (footers, exhibit lists, certification signatures)
# ================================================================
def postprocess_text(text):

    # Remove page/line artifacts (common in EDGAR dumps)
    text = re.sub(r"Page \d+ of \d+", " ", text)

    # Remove repeated ticker headings or titles in ALL CAPS spam
    text = re.sub(r"\b[A-Z0-9&\.\-]{8,}\b", " ", text)

    # Remove typical SEC boilerplate clutter
    patterns = [
        r"SIGNATURES.*$",                      # Signatures section
        r"EXHIBIT\s+\d+.*$",                   # Exhibit list headings
        r"Cover Page.*?Form 10",               # Cover page junk
        r"INDEX TO CONSOLIDATED.*$",           # Index pages
        r"See accompanying notes",             # Finance-only filler
    ]

    for p in patterns:
        text = re.sub(p, " ", text, flags=re.IGNORECASE | re.DOTALL)

    # Remove consecutive duplicated words
    text = re.sub(r'\b(\w+)( \1\b)+', r'\1', text)

    # Normalize whitespace again
    text = re.sub(r'\s+', ' ', text)

    return text.strip()

# ================================================================
# 4. Main driver — read all HTM files recursively and clean them
# ================================================================
def process_all_files(src_root, dst_root):
    """
    Recursively read all .htm files in src_root.
    Clean and save them to dst_root with identical folder structure.
    """

    for root, dirs, files in os.walk(src_root):

        for file in files:
            if file.lower().endswith(".htm"):

                src_path = os.path.join(root, file)
                print(f"Processing {src_path}")

                with open(src_path, "r", encoding="utf-8", errors="ignore") as f:
                    html = f.read()

                # Run through cleaning pipeline
                text = clean_html_text(html)
                text = remove_financials(text)     # <-- SAFE removal
                text = postprocess_text(text)

                # Build destination path
                rel_path = os.path.relpath(root, src_root)
                out_dir = os.path.join(dst_root, rel_path)
                os.makedirs(out_dir, exist_ok=True)

                out_file = os.path.join(out_dir, file.replace(".htm", "_cleaned.txt"))

                with open(out_file, "w", encoding="utf-8") as f:
                    f.write(text)

                print(f"Saved → {out_file}")


# ================================================================
# 5. Run it
# ================================================================

src_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original"
dst_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1"

process_all_files(src_folder, dst_folder)
# Out:
# Processing /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2024-Q1-10Q.htm
# Saved → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q1-10Q_cleaned.txt
# Processing /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2013-Q1-10Q.htm
# Saved → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q1-10Q_cleaned.txt
# Processing /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2020-Q3-10K.htm
# Saved → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2020-Q3-10K_cleaned.txt
# Processing /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2017-Q3-10K.htm
# Saved → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q3-10K_cleaned.txt
# Processing /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2010-Q4-10Q.htm
# Saved → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q4-10Q_cleaned.txt
# Processing /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2006-Q3-10K.htm
# Saved → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2006-Q3-10K_cleaned.txt
# Processing /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2011-Q2-10Q.htm
# Saved → /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q2-10Q_cleaned.txt
# Processing /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original/CTAS/CTAS-2008-Q2-10Q.htm
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 134
#     131 src_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original"
#     132 dst_folder = "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1"
# --> 134 process_all_files(src_folder, dst_folder)
#
# Cell In[28], line 110, in process_all_files(src_root, dst_root)
#     107     html = f.read()
#     109 # Run through cleaning pipeline
# --> 110 text = clean_html_text(html)
#     111 text = remove_financials(text)     # <-- SAFE removal
#     112 text = postprocess_text(text)
#
# Cell In[28], line 11, in clean_html_text(html)
#      10 def clean_html_text(html):
# ---> 11     soup = BeautifulSoup(html, "lxml")
#      13     # 1. Remove all tables
#      14     for t in soup.find_all("table"):
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/__init__.py:335, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333 self.builder.initialize_soup(self)
#     334 try:
# --> 335     self._feed()
#     336     success = True
#     337     break
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/__init__.py:478, in BeautifulSoup._feed(self)
#     475 # Convert the document to Unicode.
#     476 self.builder.reset()
# --> 478 self.builder.feed(self.markup)
#     479 # Close out any unfinished strings and close all the open tags.
#     480 self.endData()
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/builder/_lxml.py:378, in LXMLTreeBuilder.feed(self, markup)
#     376 try:
#     377     self.parser = self.parser_for(encoding)
# --> 378     self.parser.feed(markup)
#     379     self.parser.close()
#     380 except (UnicodeDecodeError, LookupError, etree.ParserError) as e:
#
# File src/lxml/parser.pxi:1259, in lxml.etree._FeedParser.feed()
#
# File src/lxml/parser.pxi:1379, in lxml.etree._FeedParser.feed()
#
# File src/lxml/parsertarget.pxi:168, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src/lxml/parsertarget.pxi:156, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src/lxml/etree.pyx:334, in lxml.etree._ExceptionContext._raise_if_stored()
#
# File src/lxml/saxparser.pxi:516, in lxml.etree._handleSaxEndNoNs()
#
# File src/lxml/parsertarget.pxi:99, in lxml.etree._PythonSaxParserTarget._handleSaxEnd()
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/builder/_lxml.py:325, in LXMLTreeBuilderForXML.end(self, name)
#     323             nsprefix = inverted_nsmap[namespace]
#     324             break
# --> 325 self.soup.handle_endtag(name, nsprefix)
#     326 if len(self.nsmaps) > 1:
#     327     # This tag, or one of its parents, introduced a namespace
#     328     # mapping, so pop it off the stack.
#     329     out_of_scope_nsmap = self.nsmaps.pop()
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/__init__.py:771, in BeautifulSoup.handle_endtag(self, name, nsprefix)
#     769 #print("End tag: " + name)
#     770 self.endData()
# --> 771 self._popToTag(name, nsprefix)
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/__init__.py:716, in BeautifulSoup._popToTag(self, name, nsprefix, inclusivePop)
#     714 if (name == t.name and nsprefix == t.prefix):
#     715     if inclusivePop:
# --> 716         most_recently_popped = self.popTag()
#     717     break
#     718 most_recently_popped = self.popTag()
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/__init__.py:558, in BeautifulSoup.popTag(self)
#     553     """This method is part of the PageElement API, but `BeautifulSoup` doesn't implement
#     554     it because there is nothing before or after it in the parse tree.
#     555     """
#     556     raise NotImplementedError("BeautifulSoup objects don't support insert_after().")
# --> 558 def popTag(self):
#     559     """Internal method called by _popToTag when a tag is closed."""
#     560     tag = self.tagStack.pop()
#
# KeyboardInterrupt:

# %%
#semiworks

import re
from pathlib import Path
from bs4 import BeautifulSoup

###############################################################################
# 1. STRIP HTML, TABLES, XBRL
###############################################################################

XBRL_PREFIXES = {
    "ix", "ixn", "xbrli", "xlink", "link", "dei",
    "us-gaap", "srt", "xbrldi"
}

def strip_html_and_xbrl(raw_html: str) -> str:
    soup = BeautifulSoup(raw_html, "lxml")

    # Remove script, style, metadata
    for tag in soup(["script", "style", "head", "noscript", "meta", "link"]):
        tag.decompose()

    # Remove tables, images, figures, SVG
    for tag in soup.find_all(["table", "img", "figure", "svg", "iframe", "object"]):
        tag.decompose()

    # Remove inline XBRL (Workiva)
    for tag in list(soup.find_all()):
        if tag.prefix and tag.prefix.lower() in XBRL_PREFIXES:
            tag.unwrap()

    text = soup.get_text("\n")

    # Clean up
    text = re.sub(r"<[^>]+>", " ", text)
    text = re.sub(r"\r", "\n", text)
    text = re.sub(r"\n{3,}", "\n\n", text)
    text = re.sub(r"[ \t]+", " ", text)

    return text.strip()


###############################################################################
# 2. DETECT FORM TYPE
###############################################################################

def detect_form_type(text: str) -> str:
    upper = text[:6000].upper()
    if "FORM 10-K" in upper:
        return "10-K"
    if "FORM 10-Q" in upper:
        return "10-Q"
    return "10-Q"   # default


###############################################################################
# 3. IMPROVED ITEM HEADER DETECTION (no more misalignment!)
###############################################################################

ITEM_PATTERN = re.compile(
    r"^\s*ITEM\s+([0-9]{1,2}[A]?)\s*[\.:–—-]?",
    re.IGNORECASE | re.MULTILINE
)

def find_all_items(text: str):
    """
    Returns list of (item_number, index) sorted by index.
    Only triggers on NEW LINES to avoid catching "itemized", etc.
    """
    items = [(m.group(1).upper(), m.start()) for m in ITEM_PATTERN.finditer(text)]
    return sorted(items, key=lambda x: x[1])


###############################################################################
# 4. MAP SEC ITEMS TO HUMAN-LABELED QUALITATIVE SECTIONS
###############################################################################

SEC_ITEMS_ORDER = [
    "1", "1A", "1B",
    "2", "3", "4", "5", "6",
    "7", "7A",
    "8", "9", "9A", "9B"
]

SECTION_LABELS_10K = {
    "1": "Item 1 - Business",
    "1A": "Item 1A - Risk Factors",
    "3": "Item 3 - Legal Proceedings",
    "7": "Item 7 - MD&A",
    "7A": "Item 7A - Market Risk",
    "9A": "Item 9A - Controls & Procedures"
}

SECTION_LABELS_10Q = {
    "1A": "Item 1A - Risk Factors",
    "2": "Item 2 - MD&A",
    "3": "Item 3 - Market Risk",
    "4": "Item 4 - Controls & Procedures"
}

def extract_items(text: str, form_type: str):
    item_positions = find_all_items(text)
    extracted = {}

    for i, (item_id, start_pos) in enumerate(item_positions):

        # Determine end of section
        end_pos = item_positions[i+1][1] if i+1 < len(item_positions) else len(text)

        block = text[start_pos:end_pos].strip()

        if form_type == "10-K" and item_id in SECTION_LABELS_10K:
            extracted[SECTION_LABELS_10K[item_id]] = block

        if form_type == "10-Q" and item_id in SECTION_LABELS_10Q:
            extracted[SECTION_LABELS_10Q[item_id]] = block

    return extracted


###############################################################################
# 5. FILTER OUT ACCOUNTING FOOTNOTES / BOILERPLATE
###############################################################################

ACCOUNTING_BLACKLIST = [
    r"see accompanying notes",
    r"consolidated balance sheets",
    r"consolidated statements",
    r"fair value",
    r"goodwill",
    r"impairment",
    r"deferred tax",
    r"fASB|ASC|ASU|FIN\s*\d+",
    r"note \d+",
    r"pcaob",
    r"audited",
    r"unaudited",
    r"in thousands",
]

ACCOUNTING_RE = re.compile("|".join(ACCOUNTING_BLACKLIST), re.IGNORECASE)

QUAL_KEYWORDS = [
    "expect", "anticipate", "believe", "forecast", "outlook",
    "demand", "pricing", "margin", "trend", "guidance",
    "customers", "volume", "expenses", "growth", "risk", "uncertainty"
]

def keep_qualitative_paragraphs(text: str):
    cleaned_paragraphs = []
    paragraphs = [p.strip() for p in text.split("\n") if p.strip()]

    for p in paragraphs:

        # Drop accounting boilerplate
        if ACCOUNTING_RE.search(p):
            continue

        # Must contain forward-looking or qualitative language
        if not any(k in p.lower() for k in QUAL_KEYWORDS):
            continue

        cleaned_paragraphs.append(p)

    return "\n".join(cleaned_paragraphs)


###############################################################################
# 6. FULL FILING PROCESSING
###############################################################################

def process_filing(path: Path) -> str:
    html = path.read_text(encoding="utf-8", errors="ignore")
    plain = strip_html_and_xbrl(html)
    form_type = detect_form_type(plain)
    sections = extract_items(plain, form_type)

    output = []
    for section_name, content in sections.items():
        q = keep_qualitative_paragraphs(content)
        if q:
            output.append(f"===== {section_name} =====\n{q}")

    return "\n\n".join(output)


###############################################################################
# 7. PROCESS COMPANY FOLDER
###############################################################################

def process_company_folder(folder: Path, out_root: Path):
    out_dir = out_root / folder.name
    out_dir.mkdir(parents=True, exist_ok=True)

    for html_file in folder.glob("*.htm"):
        out_path = out_dir / (html_file.stem + "_qualitative.txt")

        # skip if already processed
        if out_path.exists() and out_path.stat().st_size > 0:
            print(f"SKIP: {out_path.name}")
            continue

        print(f"Processing {html_file.name} ...")
        cleaned = process_filing(html_file)
        out_path.write_text(cleaned, encoding="utf-8")
        print(f"   ✔ wrote {out_path}")


###############################################################################
# 8. MAIN LOOP
###############################################################################

if __name__ == "__main__":
    root_input = Path("/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original")
    root_output = Path("/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1")

    for folder in root_input.iterdir():
        if folder.is_dir():
            print(f"\n===== Processing {folder.name} =====")
            process_company_folder(folder, root_output)
# Out:
# ===== Processing CTAS =====
# Processing CTAS-2024-Q1-10Q.htm ...
#    ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q1-10Q_qualitative.txt
# Processing CTAS-2013-Q1-10Q.htm ...
#    ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q1-10Q_qualitative.txt
# Processing CTAS-2020-Q3-10K.htm ...
#    ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2020-Q3-10K_qualitative.txt
# Processing CTAS-2017-Q3-10K.htm ...
#    ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q3-10K_qualitative.txt
# Processing CTAS-2010-Q4-10Q.htm ...
#    ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q4-10Q_qualitative.txt
# Processing CTAS-2006-Q3-10K.htm ...
#    ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2006-Q3-10K_qualitative.txt
# Processing CTAS-2011-Q2-10Q.htm ...
#    ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q2-10Q_qualitative.txt
# Processing CTAS-2008-Q2-10Q.htm ...
#    ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q2-10Q_qualitative.txt
# Processing CTAS-2022-Q4-10Q.htm ...
#    ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q4-10Q_qualitative.txt
# Processing CTAS-2015-Q4-10Q.htm ...
#    ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q4-10Q_qualitative.txt
# Processing CTAS-2023-Q2-10Q.htm ...
#    ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q2-10Q_qualitative.txt
# Processing CTAS-2007-Q1-10Q.htm ...
#    ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2007-Q1-10Q_qualitative.txt
# Processing CTAS-2014-Q2-10Q.htm ...
#    ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q2-10Q_qualitative.txt
# Processing CTAS-2009-Q4-10Q.htm ...
#    ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q4-10Q_qualitative.txt
# Processing CTAS-2018-Q4-10Q.htm ...
#    ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q4-10Q_qualitative.txt
# Processing CTAS-2016-Q1-10Q.htm ...
#    ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2016-Q1-10Q_qualitative.txt
# Processing CTAS-2021-Q1-10Q.htm ...
#    ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q1-10Q_qualitative.txt
# Processing CTAS-2012-Q3-10K.htm ...
#    ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q3-10K_qualitative.txt
# Processing CTAS-2025-Q3-10K.htm ...
#    ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q3-10K_qualitative.txt
# Processing CTAS-2019-Q2-10Q.htm ...
#    ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q2-10Q_qualitative.txt
# Processing CTAS-2015-Q3-10K.htm ...
#    ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q3-10K_qualitative.txt
# Processing CTAS-2022-Q3-10K.htm ...
#    ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q3-10K_qualitative.txt
# Processing CTAS-2009-Q3-10K.htm ...
#    ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q3-10K_qualitative.txt
# Processing CTAS-2011-Q1-10Q.htm ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 218
#     216 if folder.is_dir():
#     217     print(f"\n===== Processing {folder.name} =====")
# --> 218     process_company_folder(folder, root_output)
#
# Cell In[13], line 202, in process_company_folder(folder, out_root)
#     199     continue
#     201 print(f"Processing {html_file.name} ...")
# --> 202 cleaned = process_filing(html_file)
#     203 out_path.write_text(cleaned, encoding="utf-8")
#     204 print(f"   ✔ wrote {out_path}")
#
# Cell In[13], line 172, in process_filing(path)
#     170 def process_filing(path: Path) -> str:
#     171     html = path.read_text(encoding="utf-8", errors="ignore")
# --> 172     plain = strip_html_and_xbrl(html)
#     173     form_type = detect_form_type(plain)
#     174     sections = extract_items(plain, form_type)
#
# Cell In[13], line 15, in strip_html_and_xbrl(raw_html)
#      14 def strip_html_and_xbrl(raw_html: str) -> str:
# ---> 15     soup = BeautifulSoup(raw_html, "lxml")
#      17     # Remove script, style, metadata
#      18     for tag in soup(["script", "style", "head", "noscript", "meta", "link"]):
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/__init__.py:335, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333 self.builder.initialize_soup(self)
#     334 try:
# --> 335     self._feed()
#     336     success = True
#     337     break
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/__init__.py:478, in BeautifulSoup._feed(self)
#     475 # Convert the document to Unicode.
#     476 self.builder.reset()
# --> 478 self.builder.feed(self.markup)
#     479 # Close out any unfinished strings and close all the open tags.
#     480 self.endData()
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/builder/_lxml.py:379, in LXMLTreeBuilder.feed(self, markup)
#     377     self.parser = self.parser_for(encoding)
#     378     self.parser.feed(markup)
# --> 379     self.parser.close()
#     380 except (UnicodeDecodeError, LookupError, etree.ParserError) as e:
#     381     raise ParserRejectedMarkup(e)
#
# File src/lxml/parser.pxi:1383, in lxml.etree._FeedParser.close()
#
# File src/lxml/parser.pxi:1414, in lxml.etree._FeedParser.close()
#
# File src/lxml/parsertarget.pxi:168, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src/lxml/parsertarget.pxi:156, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src/lxml/etree.pyx:334, in lxml.etree._ExceptionContext._raise_if_stored()
#
# File src/lxml/saxparser.pxi:443, in lxml.etree._handleSaxTargetStartNoNs()
#
# File src/lxml/saxparser.pxi:458, in lxml.etree._callTargetSaxStart()
#
# File src/lxml/parsertarget.pxi:94, in lxml.etree._PythonSaxParserTarget._handleSaxStart()
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/builder/_lxml.py:301, in LXMLTreeBuilderForXML.start(self, name, attrs, nsmap)
#     299 namespace, name = self._getNsTag(name)
#     300 nsprefix = self._prefix_for_namespace(namespace)
# --> 301 self.soup.handle_starttag(
#     302     name, namespace, nsprefix, attrs,
#     303     namespaces=self.active_namespace_prefixes[-1]
#     304 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/__init__.py:742, in BeautifulSoup.handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos, namespaces)
#     724 """Called by the tree builder when a new tag is encountered.
#     725
#     726 :param name: Name of the tag.
#    (...)
#     739 don't call handle_endtag.
#     740 """
#     741 # print("Start tag %s: %s" % (name, attrs))
# --> 742 self.endData()
#     744 if (self.parse_only and len(self.tagStack) <= 1
#     745     and (self.parse_only.text
#     746          or not self.parse_only.search_tag(name, attrs))):
#     747     return None
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/__init__.py:617, in BeautifulSoup.endData(self, containerClass)
#     614     return
#     616 containerClass = self.string_container(containerClass)
# --> 617 o = containerClass(current_data)
#     618 self.object_was_parsed(o)
#
# File /opt/anaconda3/lib/python3.11/site-packages/bs4/element.py:943, in NavigableString.__new__(cls, value)
#     940 PREFIX = ''
#     941 SUFFIX = ''
# --> 943 def __new__(cls, value):
#     944     """Create a new NavigableString.
#     945
#     946     When unpickling a NavigableString, this method is called with
#    (...)
#     949     how to handle non-ASCII characters.
#     950     """
#     951     if isinstance(value, str):
#
# KeyboardInterrupt:

# %%
# og version
import re
from pathlib import Path
from bs4 import BeautifulSoup

###############################################################################
# STRIP HTML, TABLES, FIGURES, AND ALL INLINE XBRL
###############################################################################

XBRL_TAGS = [
    "ix:header", "ix:nonNumeric", "ix:nonFraction", "ix:footnote",
    "ix:hidden", "ix:references", "ix:resources"
]

def strip_html_and_xbrl(raw_html: str) -> str:
    soup = BeautifulSoup(raw_html, "lxml")

    # Remove Workiva inline XBRL blocks entirely
    for tagname in XBRL_TAGS:
        for t in soup.find_all(tagname):
            t.decompose()

    # Remove scripts, styles, metadata
    for tag in soup(["script", "style", "head", "noscript", "meta", "link"]):
        tag.decompose()

    # Remove tables, images, svgs, figures
    for tag in soup.find_all(["table", "img", "figure", "svg"]):
        tag.decompose()

    # Unwrap any remaining XML/XBRL tags to keep text
    for tag in list(soup.find_all()):
        if tag.prefix and tag.prefix.lower() in [
            "ix","ixn","xbrli","xlink","link","us-gaap","dei","srt","xbrldi"
        ]:
            tag.unwrap()

    # Extract text
    text = soup.get_text("\n")

    # Clean artifacts
    text = re.sub(r"<[^>]+>", " ", text)
    text = re.sub(r"\r", "\n", text)
    text = re.sub(r"\n{3,}", "\n\n", text)
    text = re.sub(r"[ \t]+", " ", text)

    return text.strip()


###############################################################################
# FORM TYPE DETECTION
###############################################################################

def detect_form_type(text: str) -> str:
    upper = text[:8000].upper()
    if "FORM 10-K" in upper:
        return "10-K"
    if "FORM 10-Q" in upper:
        return "10-Q"
    # Assume 10-Q when ambiguous
    return "10-Q"


###############################################################################
# ROBUST ITEM DETECTION
###############################################################################

ITEM_HEADER = re.compile(
    r"\bITEM\s*[\.\s]*"
    r"(1A|1|2|3|4|5|6|7|7A|8|9|9A)"
    r"(?!\d)"
    , flags=re.IGNORECASE
)

def find_all_items(text: str):
    """Return sorted list of (item_label, index)."""
    items = []
    for m in ITEM_HEADER.finditer(text):
        items.append((m.group(1).upper(), m.start()))
    return sorted(items, key=lambda x: x[1])


def extract_item_block(text: str, target_label: str):
    items = find_all_items(text)
    target_label = target_label.upper()

    for i, (label, pos) in enumerate(items):
        if label == target_label:
            end = items[i+1][1] if i+1 < len(items) else len(text)
            return text[pos:end].strip()
    return ""


###############################################################################
# SECTION EXTRACTION (QUALITATIVE SECTIONS ONLY)
###############################################################################

def extract_qualitative_sections(text: str):
    ftype = detect_form_type(text)
    sections = {}

    if ftype == "10-K":
        sections["Item 1 - Business"] = extract_item_block(text, "1")
        sections["Item 1A - Risk Factors"] = extract_item_block(text, "1A")
        sections["Item 3 - Legal Proceedings"] = extract_item_block(text, "3")
        sections["Item 7 - MD&A"] = extract_item_block(text, "7")
        sections["Item 7A - Market Risk"] = extract_item_block(text, "7A")

    else:  # 10-Q
        sections["Item 1A - Risk Factors"] = extract_item_block(text, "1A")
        sections["Item 2 - MD&A"] = extract_item_block(text, "2")
        sections["Item 3 - Market Risk"] = extract_item_block(text, "3")
        sections["Item 4 - Controls & Procedures"] = extract_item_block(text, "4")

    return {k: v for k, v in sections.items() if v.strip()}


###############################################################################
# QUALITATIVE FILTER — REMOVE TABLE REMNANTS AND PURELY NUMERIC LINES
###############################################################################

QUAL_KEYWORDS = [
    "demand","volume","pricing","margin","cost","expenses","growth",
    "decline","headwind","tailwind","outlook","guidance","expect",
    "anticipate","forecast","trend","liquidity","cash flow","capital",
    "backlog","pipeline","customers","inflation","foreign exchange",
    "fx","currency"
]

def is_qualitative_line(line: str):
    s = line.strip()
    if len(s) < 40:
        return False

    letters = sum(c.isalpha() for c in s)
    digits = sum(c.isdigit() for c in s)

    alpha_ratio = letters / max(len(s), 1)
    digit_ratio = digits / max(len(s), 1)

    has_sentence = "." in s
    has_keyword = any(k in s.lower() for k in QUAL_KEYWORDS)
    numeric_heavy = digit_ratio > 0.30 and alpha_ratio < 0.40

    if numeric_heavy and not has_keyword:
        return False
    if not has_sentence and not has_keyword:
        return False
    if alpha_ratio < 0.40 and not has_keyword:
        return False

    return True


def keep_qualitative_narrative(text: str) -> str:
    kept = [l.strip() for l in text.split("\n") if is_qualitative_line(l)]
    return "\n".join(kept).strip()


###############################################################################
# PROCESS ONE FILING
###############################################################################

def process_filing(html_path: Path) -> str:
    raw_html = html_path.read_text(encoding="utf-8", errors="ignore")
    plain = strip_html_and_xbrl(raw_html)
    sections = extract_qualitative_sections(plain)

    output_blocks = []
    for sec_name, sec_text in sections.items():
        cleaned = keep_qualitative_narrative(sec_text)
        if cleaned:
            output_blocks.append(f"===== {sec_name} =====\n{cleaned}")

    return "\n\n".join(output_blocks)


###############################################################################
# PROCESS A COMPANY FOLDER (SKIPS ALREADY CLEANED FILES)
###############################################################################

def process_company_folder(folder: Path, out_root: Path):
    out_dir = out_root / folder.name
    out_dir.mkdir(parents=True, exist_ok=True)

    for html_file in folder.glob("*.htm"):
        out_path = out_dir / (html_file.stem + "_qualitative.txt")

        # skip if already processed
        if out_path.exists() and out_path.stat().st_size > 0:
            print(f"SKIP (exists): {out_path.name}")
            continue

        print(f"Processing {html_file.name} ...")
        cleaned = process_filing(html_file)
        out_path.write_text(cleaned, encoding="utf-8")
        print(f"  ✔ wrote {out_path}")


###############################################################################
# MAIN EXECUTION
###############################################################################

if __name__ == "__main__":
    root_input = Path("/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original")
    root_output = Path("/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1")

    # Automatically detect tickers (subfolders)
    for folder in root_input.iterdir():
        if folder.is_dir():
            print(f"\n===== Processing {folder.name} =====")
            process_company_folder(folder, root_output)
# Out:
# ===== Processing CTAS =====
# Processing CTAS-2024-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q1-10Q_qualitative.txt
# Processing CTAS-2013-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q1-10Q_qualitative.txt
# Processing CTAS-2020-Q3-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2020-Q3-10K_qualitative.txt
# Processing CTAS-2017-Q3-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q3-10K_qualitative.txt
# Processing CTAS-2010-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q4-10Q_qualitative.txt
# Processing CTAS-2006-Q3-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2006-Q3-10K_qualitative.txt
# Processing CTAS-2011-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q2-10Q_qualitative.txt
# Processing CTAS-2008-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q2-10Q_qualitative.txt
# Processing CTAS-2022-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q4-10Q_qualitative.txt
# Processing CTAS-2015-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q4-10Q_qualitative.txt
# Processing CTAS-2023-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q2-10Q_qualitative.txt
# Processing CTAS-2007-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2007-Q1-10Q_qualitative.txt
# Processing CTAS-2014-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q2-10Q_qualitative.txt
# Processing CTAS-2009-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q4-10Q_qualitative.txt
# Processing CTAS-2018-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q4-10Q_qualitative.txt
# Processing CTAS-2016-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2016-Q1-10Q_qualitative.txt
# Processing CTAS-2021-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q1-10Q_qualitative.txt
# Processing CTAS-2012-Q3-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q3-10K_qualitative.txt
# Processing CTAS-2025-Q3-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q3-10K_qualitative.txt
# Processing CTAS-2019-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q2-10Q_qualitative.txt
# Processing CTAS-2015-Q3-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q3-10K_qualitative.txt
# Processing CTAS-2022-Q3-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q3-10K_qualitative.txt
# Processing CTAS-2009-Q3-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q3-10K_qualitative.txt
# Processing CTAS-2011-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q1-10Q_qualitative.txt
# Processing CTAS-2024-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q2-10Q_qualitative.txt
# Processing CTAS-2013-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q2-10Q_qualitative.txt
# Processing CTAS-2018-Q3-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q3-10K_qualitative.txt
# Processing CTAS-2025-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q4-10Q_qualitative.txt
# Processing CTAS-2012-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q4-10Q_qualitative.txt
# Processing CTAS-2016-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2016-Q2-10Q_qualitative.txt
# Processing CTAS-2021-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q2-10Q_qualitative.txt
# Processing CTAS-2019-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q1-10Q_qualitative.txt
# Processing CTAS-2017-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q4-10Q_qualitative.txt
# Processing CTAS-2020-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2020-Q4-10Q_qualitative.txt
# Processing CTAS-2006-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2006-Q4-10Q_qualitative.txt
# Processing CTAS-2010-Q3-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q3-10K_qualitative.txt
# Processing CTAS-2008-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q1-10Q_qualitative.txt
# Processing CTAS-2023-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q1-10Q_qualitative.txt
# Processing CTAS-2007-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2007-Q2-10Q_qualitative.txt
# Processing CTAS-2014-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q1-10Q_qualitative.txt
# Processing CTAS-2009-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q2-10Q_qualitative.txt
# Processing CTAS-2023-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q4-10Q_qualitative.txt
# Processing CTAS-2014-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q4-10Q_qualitative.txt
# Processing CTAS-2022-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q2-10Q_qualitative.txt
# Processing CTAS-2015-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q2-10Q_qualitative.txt
# Processing CTAS-2008-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q4-10Q_qualitative.txt
# Processing CTAS-2019-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q4-10Q_qualitative.txt
# Processing CTAS-2017-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q1-10Q_qualitative.txt
# Processing CTAS-2020-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2020-Q1-10Q_qualitative.txt
# Processing CTAS-2013-Q3-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q3-10K_qualitative.txt
# Processing CTAS-2024-Q3-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q3-10K_qualitative.txt
# Processing CTAS-2018-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q2-10Q_qualitative.txt
# Processing CTAS-2025-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q1-10Q_qualitative.txt
# Processing CTAS-2012-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q1-10Q_qualitative.txt
# Processing CTAS-2021-Q3-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q3-10K_qualitative.txt
# Processing CTAS-2016-Q3-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2016-Q3-10K_qualitative.txt
# Processing CTAS-2011-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q4-10Q_qualitative.txt
# Processing CTAS-2007-Q3-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2007-Q3-10K_qualitative.txt
# Processing CTAS-2010-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q2-10Q_qualitative.txt
# Processing CTAS-2017-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2017-Q2-10Q_qualitative.txt
# Processing CTAS-2018-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2018-Q1-10Q_qualitative.txt
# Processing CTAS-2016-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2016-Q4-10Q_qualitative.txt
# Processing CTAS-2021-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2021-Q4-10Q_qualitative.txt
# Processing CTAS-2007-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2007-Q4-10Q_qualitative.txt
# Processing CTAS-2011-Q3-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q3-10K_qualitative.txt
# Processing CTAS-2009-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2009-Q1-10Q_qualitative.txt
# Processing CTAS-2022-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2022-Q1-10Q_qualitative.txt
# Processing CTAS-2015-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2015-Q1-10Q_qualitative.txt
# Processing CTAS-2014-Q3-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2014-Q3-10K_qualitative.txt
# Processing CTAS-2023-Q3-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2023-Q3-10K_qualitative.txt
# Processing CTAS-2008-Q3-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2008-Q3-10K_qualitative.txt
# Processing CTAS-2010-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2010-Q1-10Q_qualitative.txt
# Processing CTAS-2025-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2025-Q2-10Q_qualitative.txt
# Processing CTAS-2012-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2012-Q2-10Q_qualitative.txt
# Processing CTAS-2019-Q3-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2019-Q3-10K_qualitative.txt
# Processing CTAS-2011-Q2-10K-A.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2011-Q2-10K-A_qualitative.txt
# Processing CTAS-2024-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2024-Q4-10Q_qualitative.txt
# Processing CTAS-2013-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CTAS/CTAS-2013-Q4-10Q_qualitative.txt
#
# ===== Processing DXC =====
# Processing DXC-2025-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2025-Q4-10Q_qualitative.txt
# Processing DXC-2021-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2021-Q3-10Q_qualitative.txt
# Processing DXC-2023-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2023-Q1-10Q_qualitative.txt
# Processing DXC-2022-Q2-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2022-Q2-10K_qualitative.txt
# Processing DXC-2019-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2019-Q1-10Q_qualitative.txt
# Processing DXC-2020-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2020-Q4-10Q_qualitative.txt
# Processing DXC-2017-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2017-Q4-10Q_qualitative.txt
# Processing DXC-2018-Q2-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2018-Q2-10K_qualitative.txt
# Processing DXC-2024-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2024-Q3-10Q_qualitative.txt
# Processing DXC-2023-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2023-Q3-10Q_qualitative.txt
# Processing DXC-2019-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2019-Q3-10Q_qualitative.txt
# Processing DXC-2025-Q2-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2025-Q2-10K_qualitative.txt
# Processing DXC-2024-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2024-Q1-10Q_qualitative.txt
# Processing DXC-2020-Q2-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2020-Q2-10K_qualitative.txt
# Processing DXC-2018-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2018-Q4-10Q_qualitative.txt
# Processing DXC-2021-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2021-Q1-10Q_qualitative.txt
# Processing DXC-2022-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2022-Q4-10Q_qualitative.txt
# Processing DXC-2022-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2022-Q1-10Q_qualitative.txt
# Processing DXC-2023-Q2-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2023-Q2-10K_qualitative.txt
# Processing DXC-2018-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2018-Q1-10Q_qualitative.txt
# Processing DXC-2021-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2021-Q4-10Q_qualitative.txt
# Processing DXC-2019-Q2-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2019-Q2-10K_qualitative.txt
# Processing DXC-2025-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2025-Q3-10Q_qualitative.txt
# Processing DXC-2024-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2024-Q4-10Q_qualitative.txt
# Processing DXC-2017-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2017-Q3-10Q_qualitative.txt
# Processing DXC-2020-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2020-Q3-10Q_qualitative.txt
# Processing DXC-2021-Q2-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2021-Q2-10K_qualitative.txt
# Processing DXC-2019-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2019-Q4-10Q_qualitative.txt
# Processing DXC-2020-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2020-Q1-10Q_qualitative.txt
# Processing DXC-2017-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2017-Q1-10Q_qualitative.txt
# Processing DXC-2023-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2023-Q4-10Q_qualitative.txt
# Processing DXC-2022-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2022-Q3-10Q_qualitative.txt
# Processing DXC-2018-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2018-Q3-10Q_qualitative.txt
# Processing DXC-2024-Q2-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2024-Q2-10K_qualitative.txt
# Processing DXC-2025-Q1-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/DXC/DXC-2025-Q1-10Q_qualitative.txt
#
# ===== Processing CNP =====
# Processing CNP-2020-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2020-Q2-10Q_qualitative.txt
# Processing CNP-2017-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2017-Q2-10Q_qualitative.txt
# Processing CNP-2025-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q3-10Q_qualitative.txt
# Processing CNP-2021-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2021-Q4-10Q_qualitative.txt
# Processing CNP-2016-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2016-Q4-10Q_qualitative.txt
# Processing CNP-2021-Q1-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2021-Q1-10K_qualitative.txt
# Processing CNP-2016-Q1-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2016-Q1-10K_qualitative.txt
# Processing CNP-2017-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2017-Q3-10Q_qualitative.txt
# Processing CNP-2020-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2020-Q3-10Q_qualitative.txt
# Processing CNP-2025-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q2-10Q_qualitative.txt
# Processing CNP-2024-Q1-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2024-Q1-10K_qualitative.txt
# Processing CNP-2024-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2024-Q4-10Q_qualitative.txt
# Processing CNP-2014-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2014-Q4-10Q_qualitative.txt
# Processing CNP-2023-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2023-Q4-10Q_qualitative.txt
# Processing CNP-2023-Q1-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2023-Q1-10K_qualitative.txt
# Processing CNP-2015-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2015-Q2-10Q_qualitative.txt
# Processing CNP-2022-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2022-Q2-10Q_qualitative.txt
# Processing CNP-2019-Q1-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2019-Q1-10K_qualitative.txt
# Processing CNP-2019-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2019-Q4-10Q_qualitative.txt
# Processing CNP-2018-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2018-Q2-10Q_qualitative.txt
# Processing CNP-2025-Q4-10Q-A.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q4-10Q-A_qualitative.txt
# Processing CNP-2018-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2018-Q3-10Q_qualitative.txt
# Processing CNP-2022-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2022-Q3-10Q_qualitative.txt
# Processing CNP-2015-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2015-Q3-10Q_qualitative.txt
# Processing CNP-2024-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2024-Q2-10Q_qualitative.txt
# Processing CNP-2016-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2016-Q3-10Q_qualitative.txt
# Processing CNP-2021-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2021-Q3-10Q_qualitative.txt
# Processing CNP-2025-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q4-10Q_qualitative.txt
# Processing CNP-2025-Q1-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2025-Q1-10K_qualitative.txt
# Processing CNP-2024-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2024-Q3-10Q_qualitative.txt
# Processing CNP-2021-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2021-Q2-10Q_qualitative.txt
# Processing CNP-2016-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2016-Q2-10Q_qualitative.txt
# Processing CNP-2020-Q1-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2020-Q1-10K_qualitative.txt
# Processing CNP-2017-Q1-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2017-Q1-10K_qualitative.txt
# Processing CNP-2020-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2020-Q4-10Q_qualitative.txt
# Processing CNP-2017-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2017-Q4-10Q_qualitative.txt
# Processing CNP-2019-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2019-Q3-10Q_qualitative.txt
# Processing CNP-2023-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2023-Q3-10Q_qualitative.txt
# Processing CNP-2014-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2014-Q3-10Q_qualitative.txt
# Processing CNP-2015-Q1-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2015-Q1-10K_qualitative.txt
# Processing CNP-2022-Q1-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2022-Q1-10K_qualitative.txt
# Processing CNP-2015-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2015-Q4-10Q_qualitative.txt
# Processing CNP-2022-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2022-Q4-10Q_qualitative.txt
# Processing CNP-2014-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2014-Q2-10Q_qualitative.txt
# Processing CNP-2023-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2023-Q2-10Q_qualitative.txt
# Processing CNP-2018-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2018-Q4-10Q_qualitative.txt
# Processing CNP-2018-Q1-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2018-Q1-10K_qualitative.txt
# Processing CNP-2019-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/CNP/CNP-2019-Q2-10Q_qualitative.txt
#
# ===== Processing RCL =====
# Processing RCL-2022-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2022-Q3-10Q_qualitative.txt
# Processing RCL-2018-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2018-Q3-10Q_qualitative.txt
# Processing RCL-2019-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2019-Q4-10Q_qualitative.txt
# Processing RCL-2019-Q1-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2019-Q1-10K_qualitative.txt
# Processing RCL-2018-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2018-Q2-10Q_qualitative.txt
# Processing RCL-2023-Q1-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2023-Q1-10K_qualitative.txt
# Processing RCL-2023-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2023-Q4-10Q_qualitative.txt
# Processing RCL-2022-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2022-Q2-10Q_qualitative.txt
# Processing RCL-2025-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2025-Q2-10Q_qualitative.txt
# Processing RCL-2020-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2020-Q3-10Q_qualitative.txt
# Processing RCL-2017-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2017-Q3-10Q_qualitative.txt
# Processing RCL-2024-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2024-Q4-10Q_qualitative.txt
# Processing RCL-2024-Q1-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2024-Q1-10K_qualitative.txt
# Processing RCL-2025-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2025-Q3-10Q_qualitative.txt
# Processing RCL-2017-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2017-Q2-10Q_qualitative.txt
# Processing RCL-2020-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2020-Q2-10Q_qualitative.txt
# Processing RCL-2016-Q1-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2016-Q1-10K_qualitative.txt
# Processing RCL-2021-Q1-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2021-Q1-10K_qualitative.txt
# Processing RCL-2016-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2016-Q4-10Q_qualitative.txt
# Processing RCL-2021-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2021-Q4-10Q_qualitative.txt
# Processing RCL-2018-Q1-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2018-Q1-10K_qualitative.txt
# Processing RCL-2018-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2018-Q4-10Q_qualitative.txt
# Processing RCL-2019-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2019-Q2-10Q_qualitative.txt
# Processing RCL-2022-Q4-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2022-Q4-10Q_qualitative.txt
# Processing RCL-2022-Q1-10K.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2022-Q1-10K_qualitative.txt
# Processing RCL-2023-Q2-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2023-Q2-10Q_qualitative.txt
# Processing RCL-2023-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2023-Q3-10Q_qualitative.txt
# Processing RCL-2019-Q3-10Q.htm ...
#   ✔ wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2019-Q3-10Q_qualitative.txt
# Processing RCL-2016-Q2-10Q.htm ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 211
#     209 if folder.is_dir():
#     210     print(f"\n===== Processing {folder.name} =====")
# --> 211     process_company_folder(folder, root_output)
#
# Cell In[12], line 195, in process_company_folder(folder, out_root)
#     193 print(f"Processing {html_file.name} ...")
#     194 cleaned = process_filing(html_file)
# --> 195 out_path.write_text(cleaned, encoding="utf-8")
#     196 print(f"  ✔ wrote {out_path}")
#
# File /opt/anaconda3/lib/python3.11/pathlib.py:1078, in Path.write_text(self, data, encoding, errors, newline)
#    1075     raise TypeError('data must be str, not %s' %
#    1076                     data.__class__.__name__)
#    1077 encoding = io.text_encoding(encoding)
# -> 1078 with self.open(mode='w', encoding=encoding, errors=errors, newline=newline) as f:
#    1079     return f.write(data)
#
# File /opt/anaconda3/lib/python3.11/pathlib.py:1044, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1042 if "b" not in mode:
#    1043     encoding = io.text_encoding(encoding)
# -> 1044 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/RCL/RCL-2016-Q2-10Q_qualitative.txt'

# %%
import re
from pathlib import Path
from bs4 import BeautifulSoup

###############################################################################
# SAFE HTML + XBRL STRIPPER
###############################################################################

XBRL_PREFIXES = {
    "ix", "ixn", "link", "xlink",
    "xbrli", "xbrldi", "us-gaap", "dei", "srt"
}

def strip_html_and_xbrl(raw_html: str) -> str:
    soup = BeautifulSoup(raw_html, "lxml")

    # Remove scripts, styles, unusable headers, etc.
    for tag in soup(["script", "style", "head", "noscript", "meta", "link"]):
        tag.decompose()

    # Remove entire tables (we do not want numeric sections)
    for tbl in soup.find_all("table"):
        tbl.decompose()

    # UNWRAP inline XBRL tags so we KEEP their text
    for tag in list(soup.find_all()):
        if tag.prefix and tag.prefix.lower() in XBRL_PREFIXES:
            tag.unwrap()

    # Extract plain text
    text = soup.get_text("\n")

    # Clean remaining HTML artifacts
    text = re.sub(r"<[^>]+>", " ", text)
    text = re.sub(r"\r", "\n", text)
    text = re.sub(r"\n{3,}", "\n\n", text)
    text = re.sub(r"[ \t]+", " ", text)

    return text.strip()


###############################################################################
# FORM TYPE DETECTION (10-K vs 10-Q)
###############################################################################

def detect_form_type(text: str) -> str:
    upper = text[:8000].upper()
    if "FORM 10-K" in upper or "ANNUAL REPORT" in upper:
        return "10-K"
    if "FORM 10-Q" in upper or "QUARTERLY REPORT" in upper:
        return "10-Q"
    return "10-Q"


###############################################################################
# SECTION EXTRACTION (ITEM 1, 1A, 2, 7, etc.)
###############################################################################
###############################################################################
# BETTER ITEM DETECTION (handles line breaks + avoids false matches)
###############################################################################

ITEM_HEADER = re.compile(
    r"(?mi)^[ \t]*ITEM\s+"
    r"(1A|7A|9A|1|2|3|4|5|6|7|8|9)"
    r"(?!\d)\s*[\.\:\-–—]?",
)

def find_all_items(text: str):
    """
    Returns sorted list of (item_label, start_index).
    """
    items = []
    for m in ITEM_HEADER.finditer(text):
        label = m.group(1).upper()
        items.append((label, m.start()))
    return sorted(items, key=lambda x: x[1])


def extract_item_block_fixed(text: str, target_label: str):
    """
    Extracts the text belonging to ITEM <target_label> until the next true item.
    """
    items = find_all_items(text)
    target_label = target_label.upper()

    # Find this item in the list
    for i, (label, start_idx) in enumerate(items):
        if label == target_label:
            # End is next item OR end of text
            end_idx = items[i+1][1] if i+1 < len(items) else len(text)
            return text[start_idx:end_idx].strip()

    return ""  # Not found


def extract_qualitative_sections(text: str):
    ftype = detect_form_type(text)
    sections = {}

    if ftype == "10-K":
        sections["Item 1 - Business"] = extract_item_block_fixed(text, "1")
        sections["Item 1A - Risk Factors"] = extract_item_block_fixed(text, "1A")
        sections["Item 3 - Legal Proceedings"] = extract_item_block_fixed(text, "3")
        sections["Item 7 - MD&A"] = extract_item_block_fixed(text, "7")
        sections["Item 7A - Market Risk"] = extract_item_block_fixed(text, "7A")

    else:  # 10-Q
        sections["Item 1A - Risk Factors"] = extract_item_block_fixed(text, "1A")
        sections["Item 2 - MD&A"] = extract_item_block_fixed(text, "2")
        sections["Item 3 - Market Risk"] = extract_item_block_fixed(text, "3")
        sections["Item 4 - Controls and Procedures"] = extract_item_block_fixed(text, "4")

    # Remove empty ones
    return {k: v for k, v in sections.items() if v.strip()}



###############################################################################
# QUALITATIVE FILTER — REMOVE NUMERIC / TABLE REMNANTS
###############################################################################

QUAL_KEYWORDS = [
    "demand","volume","pricing","margin","cost","expenses","growth",
    "decline","headwind","tailwind","outlook","guidance","expect",
    "anticipate","forecast","trend","liquidity","cash flow","capital",
    "backlog","pipeline","customers","inflation","foreign exchange",
    "fx","currency"
]

def is_qualitative_line(line: str):
    s = line.strip()
    if len(s) < 40:
        return False
    if s.isupper() and " " not in s:
        return False

    letters = sum(c.isalpha() for c in s)
    digits = sum(c.isdigit() for c in s)
    alpha_ratio = letters / max(len(s), 1)
    digit_ratio = digits / max(len(s), 1)

    has_sentence = "." in s
    numeric_heavy = digit_ratio > 0.30 and alpha_ratio < 0.40

    lowered = s.lower()
    has_keyword = any(k in lowered for k in QUAL_KEYWORDS)

    if numeric_heavy and not has_keyword:
        return False
    if not has_sentence and not has_keyword:
        return False
    if alpha_ratio < 0.40 and not has_keyword:
        return False

    return True


def keep_qualitative_narrative(text: str) -> str:
    lines = text.split("\n")
    kept = [l.strip() for l in lines if is_qualitative_line(l)]
    out = "\n".join(kept)
    out = re.sub(r"\n{3,}", "\n\n", out)
    return out.strip()


###############################################################################
# PROCESS A SINGLE FILING
###############################################################################

def process_filing(html_path: Path) -> str:
    raw_html = html_path.read_text(encoding="utf-8", errors="ignore")
    plain = strip_html_and_xbrl(raw_html)
    sections = extract_qualitative_sections(plain)

    cleaned = []
    for name, sec in sections.items():
        q = keep_qualitative_narrative(sec)
        if q:
            cleaned.append(f"===== {name} =====\n{q}")

    return "\n\n".join(cleaned).strip()


###############################################################################
# PROCESS ENTIRE DIRECTORY — YOUR REQUEST
###############################################################################

def process_company_folder(company_folder: str):
    input_dir = Path(company_folder)

    output_dir = Path(
        "/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1"
    ) / input_dir.name

    # Create output directory and parents if needed
    output_dir.mkdir(parents=True, exist_ok=True)

    print(f"Output directory: {output_dir}\n")

    html_files = list(input_dir.glob("*.htm")) + list(input_dir.glob("*.html"))
    if not html_files:
        print("No HTML filings found.")
        return

    for html_file in html_files:
        print(f"Processing {html_file.name} ...")
        cleaned = process_filing(html_file)

        out_path = output_dir / (html_file.stem + "_qualitative.txt")
        out_path.write_text(cleaned, encoding="utf-8")
        print(f"  -> wrote {out_path}")

    print("\nDone!")


###############################################################################
# MAIN EXECUTION — LOOP THROUGH ALL TICKERS
###############################################################################

if __name__ == "__main__":

    tickers = ['PAYC'
        # 'PAYC','KEYS','HWM','AAPL','AAP','ABBV','ABMD','ABT','ADSK','TAP','ACN',
        # 'ADI','ADM','AEP','AES','AFL','SWKS','HES','AIG','AIZ','AKAM','ALB','HON',
        # 'ALLE','ALGN','ALK','ALL','PLD','AMGN','AAL','AMT','ANSS','APH','ARE','A',
        # 'ANTM','ADP','AVB','ATVI','AVY','AWK','AXP','AZO','PNW','BA','BAX','BR',
        # 'BBY','RHI','BDX','BF.B','BKR','BIO','WRB','BLL','BWA','CARR','CAT','CBRE',
        # 'CBOE','C','CCL','COST','CDAY','STZ','CAH','CDW','CE','CERN','FIS','CF',
        # 'CFG','JPM','CHRW','CVX','CINF','CL','CLX','CMA','CMCSA','CMG','CMS','CNC',
        # 'COF','TPR','CPB','CPRT','CHD','CRL','DXC','CSCO','CSX','CTAS','CTLT',
        # 'CTSH','CTVA','CTXS','CMI','DAL','TGT','DIS','DISH','DLR','DLTR','DHR',
        # 'DPZ','DG','DOV','OMC','MU','DRE','DHI','DRI','DTE','DUK','DVN','MS','DXCM',
        # 'EBAY','CDNS','ECL','ED','EFX','ATO','PKI','EL','EMN','EMR','ENPH','EOG',
        # 'EQR','EA','ESS','ETN','ETSY','EW','EXPD','EXR','F','RF','FANG','FAST',
        # 'FBHS','FCX','FDX','FISV','FLT','FMC','USB','FRC','BEN','FTNT','FTV','IT',
        # 'GD','GILD','GIS','GLW','GM','GNRC','GPC','GPN','GPS','GRMN','GS','GWW',
        # 'HAL','HAS','HBAN','HBI','HCA','PEAK','HD','HII','HST','HOLX','CNP','HPE',
        # 'HRL','HSIC','HSY','IBM','ICE','IDXX','IEX','IFF','ILMN','INTC','INTU',
        # 'IP','IPG','IPGP','INCY','TT','ISRG','ITW','IVZ','JBHT','JKHY','JNPR','EVRG',
        # 'MDLZ','KHC','KIM','KMB','KMI','KMX','KR','LYB','LEG','LEN','LMT','LNC',
        # 'BBWI','L','LUV','LVS','LW','LYV','MAA','MA','MAS','AME','MKC','MCD',
        # 'MCHP','MCK','CVS','MET','MGM','SPGI','MAR','MKTX','MLM','MMC','MMM','MO',
        # 'MHK','MOS','MSI','MPC','MPWR','INFO','MRNA','MRO','MSFT','ETR','MTD',
        # 'MSCI','VTRS','BAC','NCLH','NFLX','NI','NKE','NOC','NOW','NRG','NSC','XEL',
        # 'NTAP','ES','NUE','NVDA','NWL','NWSA','NXPI','ODFL','FE','OGN','OKE','ORCL',
        # 'ORLY','OTIS','OXY','COP','PAYX','PBCT','BKNG','PXD','EXC','PENN','PEP',
        # 'PFE','PFG','PG','PHM','PKG','PTC','PNC','PNR','BRO','POOL','PPG','PPL',
        # 'PGR','PRU','RE','PSX','TROW','PVH','PWR','PYPL','QCOM','QRVO','RL','RCL',
        # 'REG','REGN','RMD','RJF','O','ROK','ROL','ROST','RSG','NVR','LDOS','SBUX',
        # 'EIX','SCHW','SRE','SEE','SHW','SIVB','SLB','AOS','TFC','SNPS','SO','KEY',
        # 'SPG','STT','TRV','SYK','SWK','SYF','NLOK','SYY','TDY','TECH','TER','TFX',
        # 'TDG','GL','TMO','TRMB','TSCO','TWTR','CCI','TXN','TXT','TYL','TSN','UAL',
        # 'UAA','UDR','AEE','UHS',
        # 'ULTA','UNP','URI','WM','RTX','VTR','VFC','VIAC',
        # 'V','VLO','VMC','VNO','VRSK','VRSN','VRTX','WAB','WBA','WAT','WDC','WHR',
        # 'WMB','LNT','WST','WU','WY','WYNN','XLNX','XOM','XYL','ZBRA','ZION','ZBH','ZTS'
    ]

    root_input = Path("/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-original")
    root_output = Path("/Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1")

    for ticker in tickers:
        input_dir = root_input / ticker
        output_dir = root_output / ticker

        if not input_dir.exists():
            print(f"Skipping {ticker}: folder not found.")
            continue

        print(f"\n===== Processing {ticker} =====")
        process_company_folder(str(input_dir))
# Out:
# ===== Processing PAYC =====
# Output directory: /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC
#
# Processing PAYC-2023-Q3-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2023-Q3-10Q_qualitative.txt
# Processing PAYC-2019-Q3-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2019-Q3-10Q_qualitative.txt
# Processing PAYC-2019-Q2-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2019-Q2-10Q_qualitative.txt
# Processing PAYC-2018-Q1-10K.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2018-Q1-10K_qualitative.txt
# Processing PAYC-2018-Q4-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2018-Q4-10Q_qualitative.txt
# Processing PAYC-2023-Q2-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2023-Q2-10Q_qualitative.txt
# Processing PAYC-2022-Q4-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2022-Q4-10Q_qualitative.txt
# Processing PAYC-2015-Q4-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2015-Q4-10Q_qualitative.txt
# Processing PAYC-2022-Q1-10K.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2022-Q1-10K_qualitative.txt
# Processing PAYC-2025-Q1-10K.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2025-Q1-10K_qualitative.txt
# Processing PAYC-2025-Q4-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2025-Q4-10Q_qualitative.txt
# Processing PAYC-2021-Q3-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2021-Q3-10Q_qualitative.txt
# Processing PAYC-2016-Q3-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2016-Q3-10Q_qualitative.txt
# Processing PAYC-2024-Q2-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2024-Q2-10Q_qualitative.txt
# Processing PAYC-2017-Q4-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2017-Q4-10Q_qualitative.txt
# Processing PAYC-2020-Q4-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2020-Q4-10Q_qualitative.txt
# Processing PAYC-2017-Q1-10K.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2017-Q1-10K_qualitative.txt
# Processing PAYC-2020-Q1-10K.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2020-Q1-10K_qualitative.txt
# Processing PAYC-2016-Q2-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2016-Q2-10Q_qualitative.txt
# Processing PAYC-2021-Q2-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2021-Q2-10Q_qualitative.txt
# Processing PAYC-2024-Q3-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2024-Q3-10Q_qualitative.txt
# Processing PAYC-2018-Q2-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2018-Q2-10Q_qualitative.txt
# Processing PAYC-2019-Q4-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2019-Q4-10Q_qualitative.txt
# Processing PAYC-2019-Q1-10K.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2019-Q1-10K_qualitative.txt
# Processing PAYC-2022-Q2-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2022-Q2-10Q_qualitative.txt
# Processing PAYC-2015-Q2-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2015-Q2-10Q_qualitative.txt
# Processing PAYC-2023-Q1-10K.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2023-Q1-10K_qualitative.txt
# Processing PAYC-2023-Q4-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2023-Q4-10Q_qualitative.txt
# Processing PAYC-2015-Q3-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2015-Q3-10Q_qualitative.txt
# Processing PAYC-2022-Q3-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2022-Q3-10Q_qualitative.txt
# Processing PAYC-2018-Q3-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2018-Q3-10Q_qualitative.txt
# Processing PAYC-2016-Q1-10K.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2016-Q1-10K_qualitative.txt
# Processing PAYC-2021-Q1-10K.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2021-Q1-10K_qualitative.txt
# Processing PAYC-2016-Q4-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2016-Q4-10Q_qualitative.txt
# Processing PAYC-2021-Q4-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2021-Q4-10Q_qualitative.txt
# Processing PAYC-2025-Q3-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2025-Q3-10Q_qualitative.txt
# Processing PAYC-2017-Q2-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2017-Q2-10Q_qualitative.txt
# Processing PAYC-2020-Q2-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2020-Q2-10Q_qualitative.txt
# Processing PAYC-2024-Q4-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2024-Q4-10Q_qualitative.txt
# Processing PAYC-2024-Q1-10K.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2024-Q1-10K_qualitative.txt
# Processing PAYC-2025-Q2-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2025-Q2-10Q_qualitative.txt
# Processing PAYC-2020-Q3-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2020-Q3-10Q_qualitative.txt
# Processing PAYC-2017-Q3-10Q.htm ...
#   -> wrote /Users/clairetseng/Desktop/Research/xiu/llm-bias/ibes_aggregate/10KQ-cleaned1/PAYC/PAYC-2017-Q3-10Q_qualitative.txt
#
# Done!
